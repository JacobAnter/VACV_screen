# %%
"""
The purpose of this Jupyter notebook is to evaluate the performance of
different training modalities on the test set. The training/validation/
test split was performed on a data set containing publication-backed
VACV host factors. Previously, a data set was used that partially
contained VACV host factors hallucinated by ChatGPT.

The different training modalities are both phenotypic and PPI features,
PPI features only, phenotypic features only, phenotypic features along
with row permutation of PPI features and phenotypic features along with
column permutation of PPI features.

Additionally, as integrating both modalities turned out to deteriorate
the performance, the ablation studies were repeated without phenotypic
features, i.e. the model was trained on shuffled PPI features without
phenotypic features (row permutation of PPI features without phenotypic
features and column permutation of PPI features without phenotypic
features).
"""
# Out:
# '\nThe purpose of this Jupyter notebook is to evaluate the performance of\ndifferent training modalities on the test set. The training/validation/\ntest split was performed on a data set containing publication-backed\nVACV host factors. Previously, a data set was used that partially\ncontained VACV host factors hallucinated by ChatGPT.\n\nThe different training modalities are both phenotypic and PPI features,\nPPI features only, phenotypic features only, phenotypic features along\nwith row permutation of PPI features and phenotypic features along with\ncolumn permutation of PPI features.\n\nAdditionally, as integrating both modalities turned out to deteriorate\nthe performance, the ablation studies were repeated without phenotypic\nfeatures, i.e. the model was trained on shuffled PPI features without\nphenotypic features (row permutation of PPI features without phenotypic\nfeatures and column permutation of PPI features without phenotypic\nfeatures).\n'

# %%
import os

import performance_evaluation_utils as utils

# %% [markdown]
# # Define the Paths for the Ground Truth<br>Labels as well as for the Predictions

# %%
ground_truth_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Train_validation_test_split/scientifically_sound_host_"
    "factor_set/all_host_factors/all_hf_formatted_data/all_hf_test_"
    "set_formatted_with_probs.tsv"
)

preds_both_features = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/sample-specific_"
    "modality_gating/inference_results_both_modalities/all_hf_test_"
    "set_predictions_both_modalities_seed_{i}.tsv"
)

preds_phenotype_only = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/sample-specific_"
    "modality_gating/inference_results_only_phenotypic_features/all_"
    "hf_test_set_predictions_only_phenotype_seed_{i}.tsv"
)

preds_ppi_only = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/sample-specific_"
    "modality_gating/inference_results_only_PPI_features/all_hf_test_"
    "set_predictions_only_PPIs_seed_{i}.tsv"
)

preds_phenotype_with_ppi_row_permutation = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/sample-specific_"
    "modality_gating/inference_results_phenotype_with_row_permutation_"
    "of_PPI/all_hf_test_set_predictions_row_permutation_of_PPI_vecs_"
    "seed_{i}.tsv"
)

preds_phenotype_with_ppi_col_permutation = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/sample-specific_"
    "modality_gating/inference_results_phenotype_with_col_permutation_"
    "of_PPI/all_hf_test_set_predictions_col_permutation_of_PPI_vecs_"
    "seed_{i}.tsv"
)

preds_ppi_row_permutation_without_phenotype = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/sample-specific_"
    "modality_gating/inference_results_row_permutation_of_PPI_without_"
    "phenotype/all_hf_test_set_predictions_row_permutation_of_PPI_vecs_"
    "without_phenotype_seed_{i}.tsv"
)

preds_ppi_col_permutation_without_phenotype = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/sample-specific_"
    "modality_gating/inference_results_col_permutation_of_PPI_without_"
    "phenotype/all_hf_test_set_predictions_col_permutation_of_PPI_vecs_"
    "without_phenotype_seed_{i}.tsv"
)

# %% [markdown]
# # Evaluation for Five Different Random Seeds

# %%
utils.evaluate_cv_performance(
    preds_both_features,
    ground_truth_path,
    5,
    42,
    "inference_results_both_modalities",
    "both_modalities_model"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.7174 ± 0.0201
# PR AUC: 0.4144 ± 0.0342
# {'auroc_mean': 0.7173524590163934,
#  'auroc_std': 0.02008306454011002,
#  'pr_auc_mean': 0.41442813040635357,
#  'pr_auc_std': 0.034196989552635004,
#  'aurocs': [0.7070491803278689,
#   0.7005737704918032,
#   0.7353278688524589,
#   0.6967622950819672,
#   0.7470491803278688],
#  'pr_aucs': [0.40700671223778023,
#   0.3821388946436003,
#   0.4325531502099226,
#   0.3794606364173606,
#   0.47098125852310424],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              7.0        0.632456          0.140      0.012649
#  1    20             10.6        1.959592          0.212      0.039192
#  2    30             12.4        2.727636          0.248      0.054553
#  3    40             15.6        1.624808          0.312      0.032496
#  4    50             18.0        2.190890          0.360      0.043818
# ...

# %%
utils.evaluate_cv_performance(
    preds_phenotype_only,
    ground_truth_path,
    5,
    42,
    "inference_results_only_phenotypic_features",
    "phenotype_only_model"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.5428 ± 0.0324
# PR AUC: 0.2559 ± 0.0345
# {'auroc_mean': 0.5427622950819672,
#  'auroc_std': 0.032359505518781466,
#  'pr_auc_mean': 0.25591140041889915,
#  'pr_auc_std': 0.03450777456246384,
#  'aurocs': [0.5714754098360656,
#   0.4965573770491803,
#   0.5124590163934426,
#   0.5770491803278688,
#   0.5562704918032786],
#  'pr_aucs': [0.22896642780607543,
#   0.2155627207326227,
#   0.2418289756434001,
#   0.28987123796505654,
#   0.30332763994734113],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              4.6        0.489898          0.092      0.009798
#  1    20              8.6        1.624808          0.172      0.032496
#  2    30             10.4        2.154066          0.208      0.043081
#  3    40             11.6        1.959592          0.232      0.039192
#  4    50             12.4        2.154066          0.248      0.043081
# ...

# %%
utils.evaluate_cv_performance(
    preds_ppi_only,
    ground_truth_path,
    5,
    42,
    "inference_results_only_PPI_features",
    "ppi_only_model"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.7732 ± 0.0065
# PR AUC: 0.4506 ± 0.0085
# {'auroc_mean': 0.7732213114754098,
#  'auroc_std': 0.006542483085450648,
#  'pr_auc_mean': 0.45064538742896687,
#  'pr_auc_std': 0.008452964298436354,
#  'aurocs': [0.7704098360655738,
#   0.7713934426229508,
#   0.7658606557377049,
#   0.7730327868852459,
#   0.7854098360655738],
#  'pr_aucs': [0.4540185879523797,
#   0.46541642033084696,
#   0.4464088612200837,
#   0.4411380246601772,
#   0.44624504298134693],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              6.0        0.632456          0.120      0.012649
#  1    20             10.8        1.166190          0.216      0.023324
#  2    30             15.6        0.800000          0.312      0.016000
#  3    40             19.0        1.549193          0.380      0.030984
#  4    50             23.0        1.673320          0.460      0.033466
# ...

# %%
utils.evaluate_cv_performance(
    preds_phenotype_with_ppi_row_permutation,
    ground_truth_path,
    5,
    42,
    "inference_results_phenotype_with_row_permutation_of_PPI",
    "phenotype_with_row_permutation_of_PPI_model"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.5226 ± 0.0375
# PR AUC: 0.2555 ± 0.0299
# {'auroc_mean': 0.5225901639344261,
#  'auroc_std': 0.037457369838619074,
#  'pr_auc_mean': 0.2554589966566421,
#  'pr_auc_std': 0.02986398657337234,
#  'aurocs': [0.47245901639344257,
#   0.5132786885245901,
#   0.525327868852459,
#   0.5135245901639345,
#   0.5883606557377049],
#  'pr_aucs': [0.21013911933480345,
#   0.2969284339353384,
#   0.24092578676344253,
#   0.25229182734324207,
#   0.27700981590638407],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              5.0        1.264911          0.100      0.025298
#  1    20              8.0        1.095445          0.160      0.021909
#  2    30              9.0        1.095445          0.180      0.021909
#  3    40             10.2        1.166190          0.204      0.023324
#  4    50             11.6        1.356466          0.232      0.027129
# ...

# %%
utils.evaluate_cv_performance(
    preds_phenotype_with_ppi_col_permutation,
    ground_truth_path,
    5,
    42,
    "inference_results_phenotype_with_col_permutation_of_PPI",
    "phenotype_with_col_permutation_of_PPI_model"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.5331 ± 0.0505
# PR AUC: 0.2326 ± 0.0353
# {'auroc_mean': 0.5331147540983607,
#  'auroc_std': 0.05047995922400485,
#  'pr_auc_mean': 0.2325550420896382,
#  'pr_auc_std': 0.03532941083266144,
#  'aurocs': [0.4881147540983606,
#   0.5003278688524591,
#   0.4887704918032787,
#   0.5837704918032787,
#   0.6045901639344263],
#  'pr_aucs': [0.19461769298687254,
#   0.22865598041715146,
#   0.1936078457329182,
#   0.27475121748102066,
#   0.2711424738302282],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              4.0        1.095445          0.080      0.021909
#  1    20              6.2        0.748331          0.124      0.014967
#  2    30              8.4        1.496663          0.168      0.029933
#  3    40             10.0        1.673320          0.200      0.033466
#  4    50             11.0        1.897367          0.220      0.037947
# ...

# %%
utils.evaluate_cv_performance(
    preds_ppi_row_permutation_without_phenotype,
    ground_truth_path,
    5,
    42,
    "inference_results_row_permutation_of_PPI_without_phenotype",
    "row_permutation_of_PPI_without_phenotype_model"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.4682 ± 0.0253
# PR AUC: 0.2000 ± 0.0321
# {'auroc_mean': 0.4682131147540984,
#  'auroc_std': 0.025294178877454287,
#  'pr_auc_mean': 0.19998939367627672,
#  'pr_auc_std': 0.03208805334890049,
#  'aurocs': [0.47159836065573774,
#   0.4320081967213115,
#   0.49733606557377047,
#   0.44745901639344254,
#   0.4926639344262295],
#  'pr_aucs': [0.22489636444916308,
#   0.15687772987283194,
#   0.24464162236349088,
#   0.17400464054632647,
#   0.19952661114957126],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              3.2        1.326650          0.064      0.026533
#  1    20              5.6        1.200000          0.112      0.024000
#  2    30              6.8        1.720465          0.136      0.034409
#  3    40              8.0        2.000000          0.160      0.040000
#  4    50              9.4        1.019804          0.188      0.020396
# ...

# %%
utils.evaluate_cv_performance(
    preds_ppi_col_permutation_without_phenotype,
    ground_truth_path,
    5,
    42,
    "inference_results_col_permutation_of_PPI_without_phenotype",
    "col_permutation_of_PPI_without_phenotype_model"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.5049 ± 0.0122
# PR AUC: 0.2283 ± 0.0312
# {'auroc_mean': 0.5048688524590164,
#  'auroc_std': 0.012194297308921548,
#  'pr_auc_mean': 0.22825561246885662,
#  'pr_auc_std': 0.031165749678751468,
#  'aurocs': [0.5059836065573771,
#   0.4967213114754098,
#   0.5,
#   0.5278688524590164,
#   0.4937704918032787],
#  'pr_aucs': [0.2517668294825958,
#   0.2432629881422046,
#   0.17006802721088435,
#   0.22228992833453354,
#   0.2538902891740648],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              3.2        1.166190          0.064      0.023324
#  1    20              6.0        2.607681          0.120      0.052154
#  2    30              8.4        3.720215          0.168      0.074404
#  3    40              9.4        4.317407          0.188      0.086348
#  4    50             11.2        5.153639          0.224      0.103073
# ...

# %% [markdown]
# # Closer Investigation of the PPI-Only Model

# %%
preds_path_list = []
descriptions_list = []

for i in range(42, 47):
    current_preds_path = (
        "/Users/jacobanter/Documents/Code/VACV_screen/Positive_"
        "unlabeled_learning/Multimodal_achitecture_inference/sample-"
        "specific_modality_gating/inference_results_only_PPI_features/"
        f"all_hf_test_set_predictions_only_PPIs_seed_{i}.tsv"
    )

    preds_path_list.append(current_preds_path)

    descriptions_list.append(f"Seed {i}")

# %%
utils.plot_auroc(
    preds_path_list,
    ground_truth_path,
    descriptions_list,
    os.path.join(
        "inference_results_only_PPI_features",
        "only_PPI_model_auroc.png"
    )
)
# Out:
# [0.7704098360655738,
#  0.7713934426229508,
#  0.7658606557377049,
#  0.7730327868852459,
#  0.7854098360655738]
