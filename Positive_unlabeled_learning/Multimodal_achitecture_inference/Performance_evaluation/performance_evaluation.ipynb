# %%
"""
The purpose of this Jupyter is to evaluate the performance of different
configurations of the multimodal architecture on the PU test set.
"""
# Out:
# '\nThe purpose of this Jupyter is to evaluate the performance of different\nconfigurations of the multimodal architecture on the PU test set.\n'

# %%
import os

import pandas as pd

import performance_evaluation_utils as utils

# %% [markdown]
# # Define the Paths for the Ground Truth<br>Labels as well as for the Predictions

# %%
ground_truth_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Train_validation_test_split/data_formatting/formatted_"
    "data_PU_ratio_1_5/test_set_formatted_with_probs_pu_ratio_1_5.tsv"
)

preds_best_model_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/nnPU_"
    "loss_prior_0.05_pu_ratio_1_5_probs_concat/test_set_predictions.tsv"
)

preds_no_ppis_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/nnPU_"
    "loss_prior_0.05_pu_ratio_1_5_no_PPIs/test_set_predictions_no_"
    "PPIs.tsv"
)

preds_shuffled_labels_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/nnPU_"
    "loss_prior_0.05_pu_ratio_1_5_probs_concat_shuffled_labels/test_"
    "set_predictions_shuffled_labels.tsv"
)

# %% [markdown]
# # Performance Evaluation

# %%
# Run the performance evaluation for the best performing model
best_model_dir = "performance_best_model"

utils.evaluate_all_metrics(
    preds_best_model_path,
    ground_truth_path,
    best_model_dir,
    os.path.join(
        best_model_dir,
        "best_model_performance_top_k_comparison.tsv"
    )
)

# %%
# Run the performance evaluation for the model trained without PPI
# features
no_ppis_dir = "performance_no_ppis"

utils.evaluate_all_metrics(
    preds_no_ppis_path,
    ground_truth_path,
    no_ppis_dir,
    os.path.join(
        no_ppis_dir,
        "no_ppis_performance_top_k_comparison.tsv"
    )
)

# %%
# Run the performance evaluation for the model trained on shuffled
# labels
shuffled_labels_dir = "performance_shuffled_labels"

utils.evaluate_all_metrics(
    preds_shuffled_labels_path,
    ground_truth_path,
    shuffled_labels_dir,
    os.path.join(
        shuffled_labels_dir,
        "shuffled_labels_performance_top_k_comparison.tsv"
    )
)
