# %%
"""
The purpose of this Jupyter is to evaluate the performance of different
configurations of the multimodal architecture on the PU test set.
"""
# Out:
# '\nThe purpose of this Jupyter is to evaluate the performance of different\nconfigurations of the multimodal architecture on the PU test set.\n'

# %%
import performance_evaluation_utils as utils

# %% [markdown]
# # Define the Paths for the Ground Truth<br>Labels as well as for the Predictions

# %%
ground_truth_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Train_validation_test_split/data_formatting/formatted_"
    "data_PU_ratio_1_5/test_set_formatted_with_probs_pu_ratio_1_5.tsv"
)

preds_best_model_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/five_"
    "random_seeds/test_set_predictions_best_model_seed_42.tsv"
)

preds_no_ppis_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/five_"
    "random_seeds/test_set_predictions_no_PPIs_seed_42.tsv"
)

preds_shuffled_labels_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/five_"
    "random_seeds/test_set_predictions_shuffled_labels_seed_42.tsv"
)

# %% [markdown]
# # Performance Evaluation

# %%
utils.evaluate_all_metrics(
    [
        preds_best_model_path,
        preds_no_ppis_path,
        preds_shuffled_labels_path
    ],
    ground_truth_path,
    ["with PPI features", "without PPI features", "shuffled labels"],
    "joint_comparison"
)

# %% [markdown]
# # Evaluation for Five Different Random Seeds

# %%
# Evaluation for the best model (with PPI features)
utils.evaluate_cv_performance(
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/five_"
    "random_seeds/test_set_predictions_best_model_seed_{i}.tsv",
    ground_truth_path,
    5,
    42,
    "joint_comparison",
    "model_with_PPI_features"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.7485 ± 0.0088
# PR AUC: 0.4727 ± 0.0069
# {'auroc_mean': 0.7484801846864177,
#  'auroc_std': 0.008849641165939571,
#  'pr_auc_mean': 0.47272586867417576,
#  'pr_auc_std': 0.0068516461948199625,
#  'aurocs': [0.7607733743747596,
#   0.7459599846094651,
#   0.745575221238938,
#   0.7550981146594844,
#   0.7349942285494422],
#  'pr_aucs': [0.47332472222597816,
#   0.48311012528635217,
#   0.46859435996042575,
#   0.4627429236978366,
#   0.47585721220028576],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              7.8        0.400000       0.169565      0.008696
#  1    20             13.2        0.748331       0.286957      0.016268
#  2    30             15.8        0.979796       0.343478      0.021300
#  3    40             18.2        0.748331       0.395652      0.016268
#  4    50             20.2        1.166190       0.439130      0.025352
# ...

# %%
# Evaluation for the model trained without PPI features
utils.evaluate_cv_performance(
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/five_"
    "random_seeds/test_set_predictions_no_PPIs_seed_{i}.tsv",
    ground_truth_path,
    5,
    42,
    "joint_comparison",
    "model_without_PPI_features"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.6390 ± 0.0233
# PR AUC: 0.3942 ± 0.0172
# {'auroc_mean': 0.6390246248557137,
#  'auroc_std': 0.023334470979663586,
#  'pr_auc_mean': 0.39421144122627766,
#  'pr_auc_std': 0.01722504649431018,
#  'aurocs': [0.5973932281646787,
#   0.6530396306271642,
#   0.6440938822624085,
#   0.6663139669103502,
#   0.634282416313967],
#  'pr_aucs': [0.364186182290049,
#   0.39720493170951054,
#   0.41060020064316494,
#   0.4106641118624661,
#   0.38840177962619765],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              6.8        0.400000       0.147826      0.008696
#  1    20             11.0        0.632456       0.239130      0.013749
#  2    30             13.8        0.748331       0.300000      0.016268
#  3    40             15.8        1.166190       0.343478      0.025352
#  4    50             17.2        1.469694       0.373913      0.031950
# ...

# %%
# Evaluation for the model trained on shuffled labels
utils.evaluate_cv_performance(
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/five_"
    "random_seeds/test_set_predictions_shuffled_labels_seed_{i}.tsv",
    ground_truth_path,
    5,
    42,
    "joint_comparison",
    "model_trained_on_shuffled_labels"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.5126 ± 0.0313
# PR AUC: 0.2174 ± 0.0306
# {'auroc_mean': 0.5126490958060792,
#  'auroc_std': 0.0312782684878527,
#  'pr_auc_mean': 0.21738069589907746,
#  'pr_auc_std': 0.03061298257986004,
#  'aurocs': [0.48643709118891876,
#   0.5417468257021931,
#   0.46758368603308964,
#   0.5485282801077337,
#   0.5189495959984609],
#  'pr_aucs': [0.17067367585272863,
#   0.22837102395945602,
#   0.19810358407420192,
#   0.2606838340830653,
#   0.22907136152593532],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              2.6        0.800000       0.056522      0.017391
#  1    20              4.8        2.315167       0.104348      0.050330
#  2    30              6.8        2.925748       0.147826      0.063603
#  3    40              9.2        2.856571       0.200000      0.062099
#  4    50             10.4        2.576820       0.226087      0.056018
# ...

# %% [markdown]
# # Performance Evaluation for Best Checkpoints Based on Validation AUROC

# %%
# Define the paths
preds_best_model_best_ckpt_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/five_"
    "random_seeds_best_val_auroc_ckpt/test_set_predictions_best_model_"
    "seed_42.tsv"
)

preds_no_ppis_best_ckpt_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/five_"
    "random_seeds_best_val_auroc_ckpt/test_set_predictions_no_PPIs_"
    "seed_42.tsv"
)

preds_shuffled_labels_best_ckpt_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/five_"
    "random_seeds_best_val_auroc_ckpt/test_set_predictions_shuffled_"
    "labels_seed_42.tsv"
)

# %%
utils.evaluate_all_metrics(
    [
        preds_best_model_best_ckpt_path,
        preds_no_ppis_best_ckpt_path,
        preds_shuffled_labels_best_ckpt_path
    ],
    ground_truth_path,
    ["with PPI features", "without PPI features", "shuffled labels"],
    "joint_comparison_best_val_auroc_ckpt"
)

# %% [markdown]
# ## Evaluation for Five Different Random Seeds

# %%
# Evaluation for the model trained with PPI features
utils.evaluate_cv_performance(
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/five_"
    "random_seeds_best_val_auroc_ckpt/test_set_predictions_best_model_"
    "seed_{i}.tsv",
    ground_truth_path,
    5,
    42,
    "joint_comparison_best_val_auroc_ckpt",
    "model_with_PPI_features"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.7442 ± 0.0134
# PR AUC: 0.4599 ± 0.0176
# {'auroc_mean': 0.7441996921893035,
#  'auroc_std': 0.013366083616155426,
#  'pr_auc_mean': 0.459927396482002,
#  'pr_auc_std': 0.01758501849918013,
#  'aurocs': [0.7480761831473643,
#   0.7368699499807618,
#   0.7540400153905348,
#   0.7598114659484418,
#   0.7222008464794151],
#  'pr_aucs': [0.4344810545380199,
#   0.45171614827384077,
#   0.4545021868639706,
#   0.48383101737702705,
#   0.47510657535715145],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              7.2        0.748331       0.156522      0.016268
#  1    20             12.6        0.800000       0.273913      0.017391
#  2    30             15.4        1.019804       0.334783      0.022170
#  3    40             17.8        0.979796       0.386957      0.021300
#  4    50             20.8        1.469694       0.452174      0.031950
# ...

# %%
# Evaluation for the model trained without PPI features
utils.evaluate_cv_performance(
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/five_"
    "random_seeds_best_val_auroc_ckpt/test_set_predictions_no_PPIs_"
    "seed_{i}.tsv",
    ground_truth_path,
    5,
    42,
    "joint_comparison_best_val_auroc_ckpt",
    "model_without_PPI_features"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.6336 ± 0.0250
# PR AUC: 0.3847 ± 0.0273
# {'auroc_mean': 0.6336090804155444,
#  'auroc_std': 0.025010802943537396,
#  'pr_auc_mean': 0.3847363906217769,
#  'pr_auc_std': 0.027331875023126895,
#  'aurocs': [0.5853212774143902,
#   0.6390919584455559,
#   0.6415929203539823,
#   0.6579453636013851,
#   0.6440938822624086],
#  'pr_aucs': [0.3345616766534852,
#   0.39290158372982137,
#   0.3795503659777284,
#   0.4060560005422888,
#   0.41061232620556065],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              7.0        0.000000       0.152174      0.000000
#  1    20             12.0        0.894427       0.260870      0.019444
#  2    30             14.2        0.748331       0.308696      0.016268
#  3    40             15.8        0.400000       0.343478      0.008696
#  4    50             16.8        0.748331       0.365217      0.016268
# ...

# %%
# Evaluation for the model trained on shuffled labels
utils.evaluate_cv_performance(
    "/Users/jacobanter/Documents/Code/VACV_screen/Positive_unlabeled_"
    "learning/Multimodal_achitecture_inference/Inference_results/five_"
    "random_seeds_best_val_auroc_ckpt/test_set_predictions_shuffled_"
    "labels_seed_{i}.tsv",
    ground_truth_path,
    5,
    42,
    "joint_comparison_best_val_auroc_ckpt",
    "model_trained_on_shuffled_labels"
)
# Out:
# --- Cross-Validation / Multi-Seed Performance (k=5) ---
# AUROC:  0.5805 ± 0.0403
# PR AUC: 0.2515 ± 0.0313
# {'auroc_mean': 0.5805309734513274,
#  'auroc_std': 0.04025411042505085,
#  'pr_auc_mean': 0.25152229954281624,
#  'pr_auc_std': 0.03129874117558283,
#  'aurocs': [0.574836475567526,
#   0.598114659484417,
#   0.5914774913428241,
#   0.5083686033089649,
#   0.629857637552905],
#  'pr_aucs': [0.2438658942653892,
#   0.24579672851098813,
#   0.28287381485680296,
#   0.19974568728997136,
#   0.2853293727909297],
#  'top_k_summary':       k  #positives_mean  #positives_std  recall@k_mean  recall@k_std  \
#  0    10              2.8        0.748331       0.060870      0.016268
#  1    20              6.8        1.600000       0.147826      0.034783
#  2    30              8.8        1.600000       0.191304      0.034783
#  3    40             10.4        2.416609       0.226087      0.052535
#  4    50             12.4        2.727636       0.269565      0.059296
# ...
