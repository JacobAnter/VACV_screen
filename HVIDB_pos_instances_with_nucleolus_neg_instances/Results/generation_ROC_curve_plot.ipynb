# %%
"""
The purpose of this Jupyter notebook is to generate a plot with ROC
curves for all three benchmark models.
"""
# Out:
# '\nThe purpose of this Jupyter notebook is to generate a plot with ROC\ncurves for all three benchmark models.\n'

# %%
import importlib

import evaluation_utils

# %%
# One of the many peculiarities exhibited by Jupyter notebooks is that
# once an external file has been loaded, it isn't automatically reloaded
# This renders code development cumbersome, as the Python kernel would
# have to restarted each time changes are introduced to the external
# file
# Fortunately, there is a more sophisticated solution to this issue,
# which consists of reloading the respective external file by means of
# the `importlib` built-in library
importlib.reload(evaluation_utils)

ground_truth_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"
    "with_nucleolus_neg_instances/VACV_WR_pos_and_nucleolus_prots_neg_"
    "PPI_instances.tsv"
)

model_names = [
    "SENSE-PPI", "xCAPT5 without XGBoost",
    "xCAPT5 with default XGBoost", "xCAPT5 with fitted XGBoost",
    "MaTPIP"
]

results_files_path_list = [
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"\
    "with_nucleolus_neg_instances/Results/SENSE-PPI/results_split_"\
    "{i}/predictions_on_VACV_WR_pos_and_neg_data_set_test_set_split_"\
    "{i}_without_training.tsv",
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"\
    "with_nucleolus_neg_instances/Results/Results_xCAPT5/Results_"\
    "without_XGBoost/xCAPT5_interaction_probs_VACV_WR_10-fold_cross-"\
    "val_test_set_{i}_without_XGBoost.tsv",
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"\
    "with_nucleolus_neg_instances/Results/Results_xCAPT5/Results_with_"\
    "XGBoost_no_fitting/xCAPT5_interaction_probs_VACV_WR_10-fold_"\
    "cross-val_test_set_{i}_with_XGBoost_no_fitting.tsv",
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"\
    "with_nucleolus_neg_instances/Results/Results_xCAPT5/Results_with_"\
    "XGBoost/Inference_on_entire_combined_data_set/xCAPT5_interaction_"\
    "probs_entire_combined_data_set_with_XGBoost.tsv",
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"\
    "with_nucleolus_neg_instances/Results/Results_MaTPIP/predictions_"\
    "on_VACV_WR_pos_and_neg_data_set_test_set_split_{i}_without_"\
    "training.tsv"
]

probability_key_list = [
    "preds", "interaction_probability", "interaction_probability",
    "interaction_probability", "interaction_prob"
]

output_path = "roc_curves_for_benchmark_models.svg"

roc_auc_scores_list = evaluation_utils.generate_ROC_curves(
    ground_truth_path=ground_truth_path,
    model_names=model_names,
    results_files_path_list=results_files_path_list,
    n_fold=10,
    probability_key_list=probability_key_list,
    output_path=output_path
)

print(roc_auc_scores_list)
# Out:
# [0.7137197000276179, 0.6367641435278621, 0.6539748465084658, 0.9071535552675745, 0.4992697202098957]

# %%
# Repeat the procedure for the fine-tuned SENSE-PPI as well as the
# fine-tuned xCAPT5
ground_truth_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"
    "with_nucleolus_neg_instances/VACV_WR_pos_and_nucleolus_prots_neg_"
    "PPI_instances.tsv"
)

model_names = ["SENSE-PPI fine-tuned", "xCAPT5 with fitted XGBoost"]

results_files_path_list = [
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"\
    "with_nucleolus_neg_instances/Results/SENSE-PPI_fine-tuned/"\
    "results_split_{i}/predictions_on_VACV_WR_pos_and_neg_data_set_"\
    "test_set_split_{i}_fine-tuned.tsv",
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"\
    "with_nucleolus_neg_instances/Results/Results_xCAPT5/Results_with_"\
    "XGBoost/Inference_on_entire_combined_data_set/xCAPT5_interaction_"\
    "probs_entire_combined_data_set_with_XGBoost.tsv"
]

probability_key_list = ["preds", "interaction_probability"]

output_path = "roc_curves_for_fine-tuned_benchmark_models.svg"

roc_auc_scores_list = evaluation_utils.generate_ROC_curves(
    ground_truth_path=ground_truth_path,
    model_names=model_names,
    results_files_path_list=results_files_path_list,
    n_fold=10,
    probability_key_list=probability_key_list,
    output_path=output_path
)

print(roc_auc_scores_list)
# Out:
# [0.9110492660024219, 0.9071535552675745]

# %%
# Repeat the procedure for exclusively non-fine-tuned models
ground_truth_path = (
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"
    "with_nucleolus_neg_instances/VACV_WR_pos_and_nucleolus_prots_neg_"
    "PPI_instances.tsv"
)

model_names = [
    "SENSE-PPI", "xCAPT5 without XGBoost",
    "xCAPT5 with default XGBoost", "MaTPIP",
]

results_files_path_list = [
   "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"\
    "with_nucleolus_neg_instances/Results/SENSE-PPI/results_split_"\
    "{i}/predictions_on_VACV_WR_pos_and_neg_data_set_test_set_split_"\
    "{i}_without_training.tsv",
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"\
    "with_nucleolus_neg_instances/Results/Results_xCAPT5/Results_"\
    "without_XGBoost/xCAPT5_interaction_probs_VACV_WR_10-fold_cross-"\
    "val_test_set_{i}_without_XGBoost.tsv",
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"\
    "with_nucleolus_neg_instances/Results/Results_xCAPT5/Results_with_"\
    "XGBoost_no_fitting/xCAPT5_interaction_probs_VACV_WR_10-fold_"\
    "cross-val_test_set_{i}_with_XGBoost_no_fitting.tsv",
    "/Users/jacobanter/Documents/Code/VACV_screen/HVIDB_pos_instances_"\
    "with_nucleolus_neg_instances/Results/Results_MaTPIP/predictions_"\
    "on_VACV_WR_pos_and_neg_data_set_test_set_split_{i}_without_"\
    "training.tsv"
]

probability_key_list = [
    "preds", "interaction_probability", "interaction_probability",
    "interaction_prob"
    
]

output_path = "roc_curves_for_non-fine-tuned_benchmark_models.svg"

roc_auc_scores_list = evaluation_utils.generate_ROC_curves(
    ground_truth_path=ground_truth_path,
    model_names=model_names,
    results_files_path_list=results_files_path_list,
    n_fold=10,
    probability_key_list=probability_key_list,
    output_path=output_path
)

print(roc_auc_scores_list)
# Out:
# [0.7137197000276179, 0.6367641435278621, 0.6539748465084658, 0.4992697202098957]
