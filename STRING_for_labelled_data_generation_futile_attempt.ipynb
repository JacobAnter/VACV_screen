# %%
import numpy as np
import dask.dataframe as dd
import mechanicalsoup
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/bioinformatics/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 13.0.0. Please consider upgrading.
#   warnings.warn(

# %%
# Load the screen data
# Bear in mind that for certain columns, the data type has to be
# manually specified
dtype_dict = {
    "Ensembl_ID_OnTarget_Ensembl_GRCh38_release_87": str,
    "Ensembl_ID_OnTarget_NCBI_HeLa_phs000643_v3_p1_c1_HMB": str,
    "Gene_Description": str,
    "ID": str,
    "ID_OnTarget_Ensembl_GRCh38_release_87": str,
    "ID_OnTarget_Merge": str,
    "ID_OnTarget_NCBI_HeLa_phs000643_v3_p1_c1_HMB": str,
    "ID_OnTarget_RefSeq_20170215": str,
    "ID_manufacturer": str,
    "Name_alternatives": str,
    "PLATE_QUALITY_DESCRIPTION": str,
    "RefSeq_ID_OnTarget_RefSeq_20170215": str,
    "Seed_sequence_common": str,
    "WELL_QUALITY_DESCRIPTION": str,
    "siRNA_error": str,
    "siRNA_number": str,
    "Precursor_Name": str
}

main_csv_df = dd.read_csv(
    "VacciniaReport_20170223-0958_ZScored_conc_and_NaN_adjusted.csv",
    sep="\t",
    dtype=dtype_dict
)

# %%
# Determine the unique target genes knocked down via siRNA in this
# screen
# To this end, the feature "ID_openBIS" is employed
ID_list = np.unique(main_csv_df["ID_openBIS"]).tolist()

# The list is way too large to display it in the IDE, which is why it is
# saved to a file
# Bear in mind that with statements are preferred for the purpose of
# working with files as they automatically take care of closing files,
# even in case of exceptions/errors
with open("unique_gene_IDs_entire_screen.txt", "w") as f:
    for i, ID in enumerate(ID_list):
        if i == 0:
            f.write(ID)
        else:
            f.write(f"\n{ID}")

# %%
# Repeat this procedure for the features "Name" and
# "PublicationLink_material"
name_list = np.unique(main_csv_df["Name"]).tolist()

with open("unique_gene_names_entire_screen.txt", "w") as f:
    for i, name in enumerate(name_list):
        if i == 0:
            f.write(name)
        else:
            f.write(f"\n{name}")

publink_mat_list = np.unique(
    main_csv_df["PublicationLink_material"]
).tolist()

with open(
    "unique_entries_PublicationLink_material_entire_screen.txt", "w"
) as f:
    for i, entry in enumerate(publink_mat_list):
        if i == 0:
            f.write(entry)
        else:
            f.write(f"\n{entry}")

# %%
# The feature "ID_openBIS" contains IDs the respective siRNAs can be
# accessed with on the manufacturer's website
# The feature "WellType" harbours information as to the agent by which
# the perturbation was effected (e.g. SIRNA, CONTROL, COMPOUND,
# MIRNA_INHIBITOR, etc.)

# %%
# As a first step, only data is worked with originating from treatment
# with single siRNAs
# Single siRNAs have been obtained from three different vendors, namely
# Qiagen, Ambion and Dharmacon
# For each ID in the feature "ID_openBIS", the corresponding gene name
# is determined by looking it up on the respective manufacturer's
# website

# First, extract IDs for single siRNAs from Qiagen
# Note that due to operator precedence, i.e. "&" having precedence over
# equality checks, the equality checks must be surrounded by parentheses
single_siRNA_Qiagen = main_csv_df.loc[
    (main_csv_df["WellType"] == "SIRNA")
    &
    (main_csv_df["ID_openBIS"].str.contains("QIAGEN"))
]["ID_openBIS"]

# Now, extract IDs for single siRNAs from Ambion
single_siRNA_Ambion = main_csv_df.loc[
    (main_csv_df["WellType"] == "SIRNA")
    &
    (main_csv_df["ID_openBIS"].str.contains("AMBION"))
]["ID_openBIS"]

# Lastly, extract IDs for single siRNAs from Dharmacon
single_siRNA_Dharmacon = main_csv_df.loc[
    (main_csv_df["WellType"] == "SIRNA")
    &
    (main_csv_df["ID_openBIS"].str.contains("DHARMACON"))
]["ID_openBIS"]

# %%
# In the case of Qiagen, the manufacturer's name is prepended to the IDs
# Conveniently enough, the manufacturer's name and the actual ID are
# separated by an underscore, allowing easy separation via the split
# method
single_siRNA_Qiagen_IDs = [
    verbose_ID.split("_")[1] for verbose_ID in single_siRNA_Qiagen
]

# The manufacturer's name is also prepended to the actual IDs in the
# case of Ambion and Dharmacon
pass

# %%
# Instantiate a so-called headless browser, i.e. a web browser without
# GUI
# Note that the default string used for "user_agent" might signalise to
# the server that it is not a real web browser that is requesting
# access, potentially causing the server to block access
# Therefore, it has to be pretended that access is requested by a web
# browser
browser = mechanicalsoup.StatefulBrowser(user_agent="Mozilla/5.0")

# Look up the gene names for single siRNAs from Qiagen
Qiagen_url = "https://geneglobe.qiagen.com"
Qiagen_geneglobe_page = browser.open(Qiagen_url)
Qiagen_geneglobe_html = Qiagen_geneglobe_page.soup

# %%
#... = Qiagen_homepage_html.select_one("")

# %%
print()
# Out:
# None

# %%
print(Qiagen_geneglobe_html)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <base href="/" id="baseHref"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="QIAGEN" name="author"/>
# <meta content="ctat7fZ36roG8Mbl5UXfRfWu5gH7vpIgae2TmVCS85o" name="google-site-verification"/>
# <meta content="to04i9ksp48smuby0b62dqaaophq0x" name="facebook-domain-verification"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/favicon.ico" rel="icon"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# <link as="style" href="/sfc/fonts.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <noscript><link href="/sfc/fonts.css" rel="stylesheet"/></noscript>
# <link as="style" href="/sfc/glyphicons.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <noscript><link href="/sfc/glyphicons.css" rel="stylesheet"/></noscript>
# <style type="text/css">/* cyrillic-ext */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 300;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmSU5fCRc4AMP6lbBP.woff2) format('woff2');
#   unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
# }
# /* cyrillic */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 300;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmSU5fABc4AMP6lbBP.woff2) format('woff2');
#   unicode-range: U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 300;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmSU5fCBc4AMP6lbBP.woff2) format('woff2');
#   unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 300;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmSU5fBxc4AMP6lbBP.woff2) format('woff2');
#   unicode-range: U+0370-0377, U+037A-037F, U+0384-038A, U+038C, U+038E-03A1, U+03A3-03FF;
# }
# /* vietnamese */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 300;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmSU5fCxc4AMP6lbBP.woff2) format('woff2');
#   unicode-range: U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+0300-0301, U+0303-0304, U+0308-0309, U+0323, U+0329, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 300;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmSU5fChc4AMP6lbBP.woff2) format('woff2');
#   unicode-range: U+0100-02AF, U+0304, U+0308, U+0329, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+20AD-20C0, U+2113, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 300;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmSU5fBBc4AMP6lQ.woff2) format('woff2');
#   unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+0304, U+0308, U+0329, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
# /* cyrillic-ext */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOmCnqEu92Fr1Mu72xKKTU1Kvnz.woff2) format('woff2');
#   unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
# }
# /* cyrillic */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOmCnqEu92Fr1Mu5mxKKTU1Kvnz.woff2) format('woff2');
#   unicode-range: U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOmCnqEu92Fr1Mu7mxKKTU1Kvnz.woff2) format('woff2');
#   unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOmCnqEu92Fr1Mu4WxKKTU1Kvnz.woff2) format('woff2');
#   unicode-range: U+0370-0377, U+037A-037F, U+0384-038A, U+038C, U+038E-03A1, U+03A3-03FF;
# }
# /* vietnamese */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOmCnqEu92Fr1Mu7WxKKTU1Kvnz.woff2) format('woff2');
#   unicode-range: U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+0300-0301, U+0303-0304, U+0308-0309, U+0323, U+0329, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOmCnqEu92Fr1Mu7GxKKTU1Kvnz.woff2) format('woff2');
#   unicode-range: U+0100-02AF, U+0304, U+0308, U+0329, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+20AD-20C0, U+2113, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOmCnqEu92Fr1Mu4mxKKTU1Kg.woff2) format('woff2');
#   unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+0304, U+0308, U+0329, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
# /* cyrillic-ext */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 500;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmEU9fCRc4AMP6lbBP.woff2) format('woff2');
#   unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
# }
# /* cyrillic */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 500;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmEU9fABc4AMP6lbBP.woff2) format('woff2');
#   unicode-range: U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 500;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmEU9fCBc4AMP6lbBP.woff2) format('woff2');
#   unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 500;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmEU9fBxc4AMP6lbBP.woff2) format('woff2');
#   unicode-range: U+0370-0377, U+037A-037F, U+0384-038A, U+038C, U+038E-03A1, U+03A3-03FF;
# }
# /* vietnamese */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 500;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmEU9fCxc4AMP6lbBP.woff2) format('woff2');
#   unicode-range: U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+0300-0301, U+0303-0304, U+0308-0309, U+0323, U+0329, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 500;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmEU9fChc4AMP6lbBP.woff2) format('woff2');
#   unicode-range: U+0100-02AF, U+0304, U+0308, U+0329, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+20AD-20C0, U+2113, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 500;
#   font-display: swap;
#   src: url(https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmEU9fBBc4AMP6lQ.woff2) format('woff2');
#   unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+0304, U+0308, U+0329, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
# </style>
# <style type="text/css">/* fallback */
# @font-face {
#   font-family: 'Material Icons';
#   font-style: normal;
#   font-weight: 400;
#   src: url(https://fonts.gstatic.com/s/materialicons/v142/flUhRq6tzZclQEJ-Vdg-IuiaDsNcIhQ8tQ.woff2) format('woff2');
# }
# /* fallback */
# @font-face {
#   font-family: 'Material Icons Outlined';
#   font-style: normal;
#   font-weight: 400;
#   src: url(https://fonts.gstatic.com/s/materialiconsoutlined/v109/gok-H7zzDkdnRel8-DQ6KAXJ69wP1tGnf4ZGhUcel5euIg.woff2) format('woff2');
# }
#
# .material-icons {
#   font-family: 'Material Icons';
#   font-weight: normal;
#   font-style: normal;
#   font-size: 24px;
#   line-height: 1;
#   letter-spacing: normal;
#   text-transform: none;
#   display: inline-block;
#   white-space: nowrap;
#   word-wrap: normal;
#   direction: ltr;
#   -webkit-font-feature-settings: 'liga';
#   -webkit-font-smoothing: antialiased;
# }
#
# .material-icons-outlined {
#   font-family: 'Material Icons Outlined';
#   font-weight: normal;
#   font-style: normal;
#   font-size: 24px;
#   line-height: 1;
#   letter-spacing: normal;
#   text-transform: none;
#   display: inline-block;
#   white-space: nowrap;
#   word-wrap: normal;
#   direction: ltr;
#   -webkit-font-feature-settings: 'liga';
#   -webkit-font-smoothing: antialiased;
# }
# </style>
# <script src="https://cdn.jsdelivr.net/npm/igv@2.15.10/dist/igv.min.js"></script>
# <link data-ggfile="css" href="/assets/css/lib-gg_lib_1.6.5.css" rel="stylesheet"/>
# <script type="text/javascript">
# 			window.QAtlas = window.QAtlas || {};
# 			window.QAtlas.addCountryCodeToUrl = true;
# 			window.QAtlas.addLanguageCodeToUrl = false;
# 		</script>
# <link href="styles.f53ef8f101803d04.css" rel="stylesheet"/><style ng-transition="gg-components">[_nghost-sc114] {
#   display: block;
# }
# .header-banner[_ngcontent-sc114] {
#   min-height: 52px;
# }
# .header[_ngcontent-sc114] {
#   position: fixed;
#   top: 0;
#   left: 0;
#   right: 0;
#   background-color: #FFFFFF;
#   box-shadow: 0 2px 4px rgba(8, 35, 48, 0.24);
#   z-index: 210;
# }
# .header-content[_ngcontent-sc114] {
#   padding: 16px 24px;
#   display: flex;
#   flex-direction: row;
#   justify-content: space-between;
# }
# @media (max-width: 1079px) {
#   .header-content[_ngcontent-sc114] {
#     padding: 16px 12px;
#   }
# }
# .header-content.left-content[_ngcontent-sc114] {
#   justify-content: flex-start;
# }
# .logo-qiagen[_ngcontent-sc114] {
#   padding: 0 8px 0 0;
# }
# .logo-qiagen[_ngcontent-sc114]   img[_ngcontent-sc114] {
#   display: block;
#   width: 47px;
#   height: 40px;
# }
# .logo-geneglobe[_ngcontent-sc114] {
#   font: 500 18px / 24px "Futura W01", Arial, Helvetica, sans-serif;
#   letter-spacing: 0.15px;
#   color: #595959;
#   line-height: 40px !important;
#   padding: 0 8px;
# }
# @media (min-width: 1080px) {
#   .logo-geneglobe[_ngcontent-sc114] {
#     font: 500 20px / 28px "Futura W01", Arial, Helvetica, sans-serif;
#     letter-spacing: 0.15px;
#   }
# }
# .links[_ngcontent-sc114] {
#   flex: 1;
#   padding-right: 8px;
# }
# .buttons[_ngcontent-sc114] {
#   display: flex;
#   flex-direction: row;
# }
# .buttons[_ngcontent-sc114]   app-button-my-account[_ngcontent-sc114] {
#   margin: auto;
# }
# .button[_ngcontent-sc114] {
#   font: 400 16px / 24px "Futura W01", Arial, Helvetica, sans-serif;
#   letter-spacing: 0.4px;
#   font-weight: 500;
#   line-height: 40px;
#   display: inline-block;
#   padding: 0 8px;
#   color: #595959;
#   cursor: pointer;
#   margin: 0;
# }
# .button[_ngcontent-sc114]:hover {
#   color: #004D9F;
# }
# .button[_ngcontent-sc114]   .icon[_ngcontent-sc114] {
#   vertical-align: text-bottom;
#   width: 20px;
#   height: 20px;
# }
# .button[_ngcontent-sc114]   .icon[_ngcontent-sc114]    + span[_ngcontent-sc114] {
#   margin-left: 8px;
# }
# .button[_ngcontent-sc114]   .icon[_ngcontent-sc114]     svg {
#   display: block;
# }
# .separator[_ngcontent-sc114] {
#   margin: 8px;
#   border-left: 1px solid #BCBCBB;
#   height: 24px;
# }
# .mobile-menu[_ngcontent-sc114] {
#   top: 80px;
# }
# .mobile-content[_ngcontent-sc114] {
#   min-height: 100vh;
# }
# .for-mobile[_ngcontent-sc114] {
#   display: block;
# }
# @media (min-width: 1080px) {
#   .for-mobile[_ngcontent-sc114] {
#     display: none;
#   }
# }
# @media (max-width: 1079px) {
#   .hide-for-mobile[_ngcontent-sc114] {
#     display: none;
#   }
# }
# .cart[_ngcontent-sc114] {
#   position: relative;
# }
# .cart-count[_ngcontent-sc114] {
#   display: none;
#   width: 16px;
#   height: 16px;
#   background-color: #9E002A;
#   position: absolute;
#   top: -6px;
#   left: 22px;
#   z-index: 1;
#   border-radius: 8px;
#   font-size: 10px;
#   color: #FFFFFF;
#   line-height: 16px;
#   text-align: center;
# }
# .cart-count--show[_ngcontent-sc114] {
#   display: inline;
# }
# [_nghost-sc114]     .cookie-banner:before {
#   opacity: 0.75;
# }
# [_nghost-sc114]     .cookie-banner {
#   z-index: 10101 !important;
# }</style><style ng-transition="gg-components">.container[_ngcontent-sc120] {
#   max-width: 1284px;
#   margin: 0 auto;
#   padding: 0 16px;
# }
# .container[_ngcontent-sc120]   .container[_ngcontent-sc120] {
#   width: 100%;
#   padding: 0;
# }
# .container-fluid[_ngcontent-sc120] {
#   padding: 0 24px;
#   margin: 0 auto;
#   max-width: 1920px;
# }
# .grey[_ngcontent-sc120] {
#   background: #F9F9F9;
#   display: flex;
# }
# .insideComponent[_ngcontent-sc120]     .breadcrumbs {
#   padding: 0;
# }
# wca-breadcrumbs[_ngcontent-sc120]     .breadcrumbs {
#   padding: 32px 0;
#   margin: 0;
# }</style><link href="https://geneglobe.qiagen.com" rel="canonical"/><script src="//assets.adobedtm.com/a6b2e205f4f8/e7fdc9a69d87/launch-fb60a0c88fd6.min.js"></script><meta content="Research genes, miRNAs or pathways and find or create NGS, PCR and functional analysis products to study them. Analyze data and plan follow-up experiments." name="description"/><meta content="" name="keywords"/><title>GeneGlobe Design &amp; Analysis Hub | Plan Your Experiments With Ease | GeneGlobe</title><style ng-transition="gg-components">[_nghost-sc164] {
#         display: block;
#       }</style><style ng-transition="gg-components">.wrap[_ngcontent-sc117] {
#   width: 100%;
# }
# @media (min-width: 360px) {
#   .wrap[_ngcontent-sc117] {
#     width: 100%;
#   }
# }
# @media (min-width: 600px) {
#   .wrap[_ngcontent-sc117] {
#     width: 100%;
#   }
# }
# @media (min-width: 1080px) {
#   .wrap[_ngcontent-sc117] {
#     width: 100%;
#   }
# }
# @media (min-width: 1284px) {
#   .wrap[_ngcontent-sc117] {
#     width: 1284px;
#   }
# }
# [_nghost-sc117] {
#   display: block;
#   width: 100%;
#   font-family: "Futura W01", Arial, Helvetica, sans-serif;
#   font-size: 16px;
#   color: #595959;
# }
# .footer-top[_ngcontent-sc117] {
#   padding: 40px 0;
# }
# .wrap[_ngcontent-sc117] {
#   display: flex;
#   flex-wrap: wrap;
#   position: relative;
#   padding: 0 16px;
#   margin: 0 auto;
# }
# @media (max-width: 599px) {
#   .wrap[_ngcontent-sc117] {
#     flex-direction: column;
#   }
# }
# @media (min-width: 1080px) {
#   .wrap[_ngcontent-sc117] {
#     padding: 0 24px;
#   }
# }
# @media (max-width: 599px) {
#   .box[_ngcontent-sc117] {
#     padding-bottom: 16px;
#   }
# }
# @media (min-width: 600px) {
#   .box.country-language-selector[_ngcontent-sc117] {
#     width: 100%;
#   }
# }
# @media (min-width: 1080px) {
#   .box.country-language-selector[_ngcontent-sc117] {
#     width: 45%;
#   }
# }
# @media (min-width: 600px) {
#   .box.follow-us[_ngcontent-sc117] {
#     width: 70%;
#   }
# }
# @media (min-width: 1080px) {
#   .box.follow-us[_ngcontent-sc117] {
#     width: 30%;
#   }
# }
# @media (min-width: 600px) {
#   .box.contact-us[_ngcontent-sc117] {
#     width: 30%;
#   }
# }
# @media (min-width: 1080px) {
#   .box.contact-us[_ngcontent-sc117] {
#     width: 20%;
#   }
# }
# .box[_ngcontent-sc117]   div[_ngcontent-sc117] {
#   font-size: 20px;
#   font-weight: 400;
#   line-height: 24px;
#   margin: 0 0 16px 0;
# }
# .disclaimer[_ngcontent-sc117] {
#   width: 100%;
#   padding: 24px 0 0;
#   color: #606060;
#   font-size: 14px;
#   line-height: 18px;
# }
# @media (max-width: 599px) {
#   .disclaimer[_ngcontent-sc117] {
#     padding: 0;
#   }
# }
# .disclaimer[_ngcontent-sc117]     a {
#   color: #1043AA;
#   text-decoration: underline;
# }
# .country-language-selector[_ngcontent-sc117]   wca-footer-country[_ngcontent-sc117], .country-language-selector[_ngcontent-sc117]   wca-footer-language[_ngcontent-sc117] {
#   position: relative;
#   display: block;
#   width: 100%;
#   margin: 0 0 16px 0;
# }
# @media (min-width: 600px) {
#   .country-language-selector[_ngcontent-sc117]   wca-footer-country[_ngcontent-sc117], .country-language-selector[_ngcontent-sc117]   wca-footer-language[_ngcontent-sc117] {
#     float: left;
#     width: 90%;
#   }
# }
# @media (min-width: 1080px) {
#   .country-language-selector[_ngcontent-sc117]   wca-footer-country[_ngcontent-sc117], .country-language-selector[_ngcontent-sc117]   wca-footer-language[_ngcontent-sc117] {
#     margin: 0;
#     width: 40%;
#   }
# }
# @media (min-width: 600px) {
#   .country-language-selector[_ngcontent-sc117]   wca-footer-country[_ngcontent-sc117]:first-of-type, .country-language-selector[_ngcontent-sc117]   wca-footer-language[_ngcontent-sc117]:first-of-type {
#     margin-right: 32px;
#   }
# }
# @media (min-width: 1080px) {
#   .country-language-selector[_ngcontent-sc117]   wca-footer-country[_ngcontent-sc117]:first-of-type, .country-language-selector[_ngcontent-sc117]   wca-footer-language[_ngcontent-sc117]:first-of-type {
#     margin-right: 8px;
#   }
# }
# .follow-us[_ngcontent-sc117]   ul[_ngcontent-sc117]   li[_ngcontent-sc117], .contact-us[_ngcontent-sc117]   ul[_ngcontent-sc117]   li[_ngcontent-sc117] {
#   display: inline-block;
#   padding: 10px 30px 0 0;
# }
# .follow-us[_ngcontent-sc117]   ul[_ngcontent-sc117]   li[_ngcontent-sc117]   a[_ngcontent-sc117], .contact-us[_ngcontent-sc117]   ul[_ngcontent-sc117]   li[_ngcontent-sc117]   a[_ngcontent-sc117] {
#   font-size: 32px;
#   line-height: 32px;
#   color: #595959;
#   text-decoration: none;
#   cursor: pointer;
# }
# @media (min-width: 1080px) {
#   .follow-us[_ngcontent-sc117]   ul[_ngcontent-sc117]   li[_ngcontent-sc117]   a[_ngcontent-sc117], .contact-us[_ngcontent-sc117]   ul[_ngcontent-sc117]   li[_ngcontent-sc117]   a[_ngcontent-sc117] {
#     font-size: 18px;
#     line-height: 20px;
#   }
# }
# .follow-us[_ngcontent-sc117]   ul[_ngcontent-sc117]   li[_ngcontent-sc117]   a[_ngcontent-sc117]   .social-icon[_ngcontent-sc117], .contact-us[_ngcontent-sc117]   ul[_ngcontent-sc117]   li[_ngcontent-sc117]   a[_ngcontent-sc117]   .social-icon[_ngcontent-sc117] {
#   color: #606060;
# }
# .follow-us[_ngcontent-sc117]   ul[_ngcontent-sc117]   li[_ngcontent-sc117]   a[_ngcontent-sc117]   .social-icon[_ngcontent-sc117]:hover, .contact-us[_ngcontent-sc117]   ul[_ngcontent-sc117]   li[_ngcontent-sc117]   a[_ngcontent-sc117]   .social-icon[_ngcontent-sc117]:hover {
#   color: #1043AA;
# }
# .scroll-to-top[_ngcontent-sc117] {
#   border: 1px #BCBCBB solid;
#   background-color: transparent;
#   border-radius: 2px;
#   position: absolute;
#   top: -37px;
#   right: 16px;
#   display: block;
#   width: 40px;
#   height: 40px;
#   overflow: hidden;
#   cursor: pointer;
#   font-size: 11px;
#   line-height: 11px;
#   color: #595959;
# }
# .scroll-to-top[_ngcontent-sc117]   span[_ngcontent-sc117] {
#   display: block;
#   font-size: inherit;
#   line-height: inherit;
#   position: relative;
#   transform: rotate(-90deg);
# }
# @media (min-width: 1080px) {
#   .scroll-to-top[_ngcontent-sc117] {
#     top: 0;
#     right: 24px;
#   }
# }
# .footer-bottom[_ngcontent-sc117] {
#   padding: 24px 0;
#   background-color: #004D9F;
#   border-radius: 20px 20px 0 0;
#   color: #FFFFFF;
#   font: 400 16px / 24px "Futura W01", Arial, Helvetica, sans-serif;
#   letter-spacing: 0.4px;
# }
# .footer-bottom[_ngcontent-sc117]   .strapline[_ngcontent-sc117] {
#   font: 400 16px / 24px "Futura W01", Arial, Helvetica, sans-serif;
#   letter-spacing: 0.4px;
#   font-weight: 500;
#   margin-bottom: 24px;
# }
# .footer-bottom[_ngcontent-sc117]   .container.b2b[_ngcontent-sc117] {
#   position: relative;
# }
# .footer-bottom[_ngcontent-sc117]   .container[_ngcontent-sc117]   .copyright[_ngcontent-sc117] {
#   display: block;
# }
# @media (min-width: 1080px) {
#   .footer-bottom[_ngcontent-sc117]   .container[_ngcontent-sc117]   .copyright[_ngcontent-sc117] {
#     display: block;
#     padding-right: 16px;
#     margin-bottom: 8px;
#   }
# }
# .footer-bottom[_ngcontent-sc117]   .container[_ngcontent-sc117]   .bottom-links[_ngcontent-sc117] {
#   display: flex;
#   flex-flow: column;
# }
# @media (min-width: 600px) {
#   .footer-bottom[_ngcontent-sc117]   .container[_ngcontent-sc117]   .bottom-links[_ngcontent-sc117] {
#     flex-flow: row;
#     display: inline-flex;
#   }
#   .footer-bottom[_ngcontent-sc117]   .container[_ngcontent-sc117]   .bottom-links[_ngcontent-sc117]   [_ngcontent-sc117]:not(:first-child):before {
#     position: absolute;
#     top: -1px;
#     left: -1px;
#     content: "";
#     display: block;
#     width: 1px;
#     height: 100%;
#     background-color: #FFFFFF;
#   }
# }
# .footer-bottom[_ngcontent-sc117]   .container[_ngcontent-sc117]   .bottom-links[_ngcontent-sc117]   a[_ngcontent-sc117] {
#   position: relative;
#   display: inline-block;
#   color: inherit;
#   padding-right: 16px;
#   text-decoration: none;
#   margin-top: 16px;
#   word-break: normal;
# }
# @media (min-width: 600px) {
#   .footer-bottom[_ngcontent-sc117]   .container[_ngcontent-sc117]   .bottom-links[_ngcontent-sc117]   a[_ngcontent-sc117] {
#     padding: 0 12px;
#   }
#   .footer-bottom[_ngcontent-sc117]   .container[_ngcontent-sc117]   .bottom-links[_ngcontent-sc117]   a[_ngcontent-sc117]:first-of-type {
#     padding: 0 12px 0 0;
#   }
# }
# @media (min-width: 1080px) {
#   .footer-bottom[_ngcontent-sc117]   .container[_ngcontent-sc117]   .bottom-links[_ngcontent-sc117]   a[_ngcontent-sc117] {
#     margin-top: 0;
#   }
# }
# .accessibility-widget[_ngcontent-sc117] {
#   position: absolute;
#   top: -37px;
#   right: 72px;
# }
# @media (min-width: 1080px) {
#   .accessibility-widget[_ngcontent-sc117] {
#     top: 60px;
#     right: 24px;
#   }
# }
# .accessibility-widget__open[_ngcontent-sc117] {
#   display: block;
#   width: 40px;
#   height: 40px;
#   cursor: pointer;
#   border-radius: 50%;
#   border: 1px #BCBCBB solid;
#   padding: 4px;
# }
# .accessibility-widget__open[_ngcontent-sc117]   svg[_ngcontent-sc117] {
#   width: 30px;
#   height: 30px;
#   fill: #595959;
# }
# .b2b[_ngcontent-sc117]   .accessibility-widget[_ngcontent-sc117] {
#   top: 50%;
#   transform: translate(0, -50%);
# }
# .b2b[_ngcontent-sc117]   .accessibility-widget[_ngcontent-sc117]   .accessibility-widget__open[_ngcontent-sc117] {
#   border: 1px white solid;
# }
# .b2b[_ngcontent-sc117]   .accessibility-widget[_ngcontent-sc117]   .accessibility-widget__open[_ngcontent-sc117]   svg[_ngcontent-sc117] {
#   fill: white;
# }</style><style ng-transition="gg-components">.select-wrap[_ngcontent-sc115] {
#   position: relative;
#   display: block;
#   width: 100%;
# }
# .select-wrap[_ngcontent-sc115]    > select[_ngcontent-sc115] {
#   appearance: none;
#   position: relative;
#   display: block;
#   padding: 10px;
#   font-size: 14px;
#   line-height: 18px;
#   font-family: "Futura W01", Arial, Helvetica, sans-serif;
#   width: 100%;
#   color: #595959;
#   border: 1px solid #BCBCBB;
#   border-radius: 2px;
# }
# .select-wrap[_ngcontent-sc115]    > select[_ngcontent-sc115]::-ms-expand {
#   display: none;
# }
# .select-wrap[data-disabled][_ngcontent-sc115]    > select[_ngcontent-sc115] {
#   color: #BCBCBB;
#   border-color: #BCBCBB;
#   opacity: 0.5;
# }
# .select-wrap[data-disabled][_ngcontent-sc115]:after {
#   border-top-color: #BCBCBB;
# }
# .select-wrap[_ngcontent-sc115]:after {
#   position: absolute;
#   top: 47%;
#   right: 12px;
#   content: "";
#   display: block;
#   width: 0;
#   height: 0;
#   border-top: 3px #595959 solid;
#   border-right: 3px transparent solid;
#   border-left: 3px transparent solid;
# }
# .select-wrap.select-wrap--lang[_ngcontent-sc115]    > select[_ngcontent-sc115] {
#
#
# }
# .select-wrap.select-wrap--lang[_ngcontent-sc115]    > select[_ngcontent-sc115]:disabled {
#   color: #BCBCBB;
#   border-color: #BCBCBB;
#   opacity: 0.5;
# }</style><style ng-transition="gg-components">.select-wrap[_ngcontent-sc116] {
#   position: relative;
#   display: block;
#   width: 100%;
# }
# .select-wrap[_ngcontent-sc116]    > select[_ngcontent-sc116] {
#   appearance: none;
#   position: relative;
#   display: block;
#   padding: 10px;
#   font-size: 14px;
#   line-height: 18px;
#   font-family: "Futura W01", Arial, Helvetica, sans-serif;
#   width: 100%;
#   color: #595959;
#   border: 1px solid #BCBCBB;
#   border-radius: 2px;
# }
# .select-wrap[_ngcontent-sc116]    > select[_ngcontent-sc116]::-ms-expand {
#   display: none;
# }
# .select-wrap[data-disabled][_ngcontent-sc116]    > select[_ngcontent-sc116] {
#   color: #BCBCBB;
#   border-color: #BCBCBB;
#   opacity: 0.5;
# }
# .select-wrap[data-disabled][_ngcontent-sc116]:after {
#   border-top-color: #BCBCBB;
# }
# .select-wrap[_ngcontent-sc116]:after {
#   position: absolute;
#   top: 47%;
#   right: 12px;
#   content: "";
#   display: block;
#   width: 0;
#   height: 0;
#   border-top: 3px #595959 solid;
#   border-right: 3px transparent solid;
#   border-left: 3px transparent solid;
# }</style><style ng-transition="gg-components">[_nghost-sc99] {
#   display: inline-block;
#   position: relative;
#   width: 24px;
#   min-width: 16px;
#   overflow: hidden;
# }
# [_nghost-sc99]:before {
#   content: "";
#   display: block;
#   padding-bottom: 100%;
#   height: 0;
#   width: 100%;
#   box-sizing: border-box;
# }
# [_nghost-sc99]   .three-size-icon[_ngcontent-sc99] {
#   position: absolute;
#   width: 1em;
#   height: 1em;
#   white-space: nowrap;
#   left: 50%;
#   top: 50%;
#   transform: translate(-50%, -50%);
# }</style><style ng-transition="gg-components">[_nghost-sc400]   .container[_ngcontent-sc400] {
#   display: block;
#   margin: 0 auto;
#   padding: 0 1rem;
#   max-width: 1284px;
# }
# [_nghost-sc400]   .white[_ngcontent-sc400] {
#   background: #FFFFFF;
# }
# [_nghost-sc400]   .blue[_ngcontent-sc400] {
#   background: #004D9F;
# }
# [_nghost-sc400]   .extra-light-grey[_ngcontent-sc400] {
#   background: #F9F9F9;
# }
# [_nghost-sc400]   .super-light-blue[_ngcontent-sc400] {
#   background: #F2F7FC;
# }
# [_nghost-sc400]   .rounded-corners[_ngcontent-sc400] {
#   border-radius: 0.75rem;
# }
# @media (min-width: 1080px) {
#   .two-thirds[_ngcontent-sc400] {
#     width: 66.66666%;
#   }
# }
# .big-image[_ngcontent-sc400] {
#   display: flex;
#   justify-content: center;
#   background-repeat: no-repeat;
#   background-size: cover !important;
#   background-position: center top;
# }</style><style ng-transition="gg-components">.side-teaser-item[_ngcontent-sc307] {
#   margin-bottom: 16px;
# }</style><style ng-transition="gg-components">[_nghost-sc358]   .hero-tabs[_ngcontent-sc358] {
#   color: #595959;
# }
# [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   .component-container[_ngcontent-sc358] {
#   padding: 160px 0 0 0;
#   min-height: 500px;
#   background-position: right bottom;
#   background-repeat: no-repeat;
# }
# [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   .component-container[_ngcontent-sc358]   .container[_ngcontent-sc358] {
#   position: relative;
#   padding-top: 1rem;
#   padding-bottom: 8rem;
# }
# @media (max-width: 1079px) {
#   [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   .component-container[_ngcontent-sc358]   .container[_ngcontent-sc358] {
#     padding-bottom: 2rem;
#   }
# }
# @media (min-width: 1080px) {
#   [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   header[_ngcontent-sc358] {
#     width: 80%;
#   }
# }
# [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   header[_ngcontent-sc358]   .title[_ngcontent-sc358] {
#   font: 400 40px / 52px "Futura W01", Arial, Helvetica, sans-serif;
#   letter-spacing: 0.25px;
# }
# @media (min-width: 1080px) {
#   [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   header[_ngcontent-sc358]   .title[_ngcontent-sc358] {
#     font: 400 48px / 64px "Futura W01", Arial, Helvetica, sans-serif;
#     letter-spacing: 0;
#   }
# }
# @media (min-width: 1284px) {
#   [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   header[_ngcontent-sc358]   .title[_ngcontent-sc358] {
#     font: 400 48px / 64px "Futura W01", Arial, Helvetica, sans-serif;
#   }
# }
# @media (min-width: 1284px) and (min-width: 1080px) {
#   [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   header[_ngcontent-sc358]   .title[_ngcontent-sc358] {
#     font: 400 60px / 80px "Futura W01", Arial, Helvetica, sans-serif;
#     letter-spacing: -0.5px;
#   }
# }
# [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   header[_ngcontent-sc358]   .description[_ngcontent-sc358] {
#   font: 400 16px / 24px "Futura W01", Arial, Helvetica, sans-serif;
#   letter-spacing: 0.25px;
# }
# @media (min-width: 1080px) {
#   [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   header[_ngcontent-sc358]   .description[_ngcontent-sc358] {
#     font: 400 18px / 28px "Futura W01", Arial, Helvetica, sans-serif;
#     letter-spacing: 0.5px;
#   }
# }
# [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   .search-input[_ngcontent-sc358] {
#   color: #595959;
#   background-color: #FFFFFF;
#   padding: 0 20px;
#   border-radius: 16px;
#   margin: 32px 0 24px 0;
#   box-shadow: 0 2px 4px rgba(8, 35, 48, 0.24);
# }
# [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   .explore-link[_ngcontent-sc358] {
#   font: 400 16px / 24px "Futura W01", Arial, Helvetica, sans-serif;
#   letter-spacing: 0.4px;
#   font-weight: 500;
# }
# [_nghost-sc358]   .hero-tabs[_ngcontent-sc358]   .explore-link[_ngcontent-sc358]    > a[_ngcontent-sc358] {
#   color: #595959;
#   text-decoration: underline;
# }
# [_nghost-sc358]   .hero-tabs.blue[_ngcontent-sc358] {
#   color: #FFFFFF;
# }
# [_nghost-sc358]   .hero-tabs.blue[_ngcontent-sc358]   .explore-link[_ngcontent-sc358]     a {
#   color: #FFFFFF;
# }
# [_nghost-sc358]   .hero-tabs.blue[_ngcontent-sc358]   .explore-link[_ngcontent-sc358]     a:hover {
#   text-decoration: underline;
# }
# [_nghost-sc358]     a {
#   cursor: pointer;
# }</style><style ng-transition="gg-components">.chip-list-navigation[_ngcontent-sc357]   .mat-tab-nav-bar[_ngcontent-sc357] {
#   border: 0;
# }
# .chip-list-navigation[_ngcontent-sc357]   .mat-chip-list[_ngcontent-sc357] {
#   display: block;
#   white-space: nowrap;
# }
# .chip-list-navigation[_ngcontent-sc357]   .mat-chip-list[_ngcontent-sc357]     .mat-chip-list-wrapper {
#   display: block;
#   margin: 0;
# }
# .chip-list-navigation[_ngcontent-sc357]   .mat-chip-list[_ngcontent-sc357]   .mat-chip[_ngcontent-sc357] {
#   font: 400 16px / 24px "Futura W01", Arial, Helvetica, sans-serif;
#   letter-spacing: 0.4px;
#   font-weight: 500;
#   justify-content: space-between;
#   line-height: 24px;
#   background-color: transparent;
#   color: #595959;
#   min-height: 40px;
#   border-radius: 10px;
#   vertical-align: top;
#   cursor: pointer;
#   border: 1px #BCBCBB solid;
#   -webkit-user-select: none;
#           user-select: none;
#   margin: 0 16px 0 0;
#   padding-left: 16px;
#   padding-right: 16px;
#   min-width: unset;
#   opacity: 1;
#   box-shadow: none;
# }
# .chip-list-navigation[_ngcontent-sc357]   .mat-chip-list[_ngcontent-sc357]   .mat-chip[_ngcontent-sc357]:last-child {
#   margin: 0;
# }
# .chip-list-navigation[_ngcontent-sc357]   .mat-chip-list[_ngcontent-sc357]   .mat-chip[_ngcontent-sc357]   .icon[_ngcontent-sc357] {
#   margin: 0 12px 0 0;
# }
# .chip-list-navigation[_ngcontent-sc357]   .mat-chip-list[_ngcontent-sc357]   .mat-chip.active[_ngcontent-sc357] {
#   background-color: #F2F7FC;
#   color: #004D9F;
#   border-color: #004D9F;
#   border-width: 2px;
#   padding-left: 15px;
#   padding-right: 15px;
# }
# .chip-list-navigation[_ngcontent-sc357]   .mat-chip-list[_ngcontent-sc357]   .mat-chip[_ngcontent-sc357]    > gg-lib-badge[_ngcontent-sc357] {
#   margin-left: 10px;
# }
# .chip-list-navigation[_ngcontent-sc357]   .mat-chip-list[_ngcontent-sc357]   .mat-chip.mat-standard-chip[_ngcontent-sc357]::after {
#   background: transparent;
# }
# .chip-list-navigation.blue[_ngcontent-sc357]     .mat-tab-header-pagination-chevron {
#   border-color: #FFFFFF;
# }
# .chip-list-navigation.blue[_ngcontent-sc357]     .mat-tab-header-pagination-disabled .mat-tab-header-pagination-chevron {
#   border-color: #CEE0F3;
# }
# .chip-list-navigation.blue[_ngcontent-sc357]   .mat-chip-list[_ngcontent-sc357]   .mat-chip[_ngcontent-sc357] {
#   background-color: transparent;
#   color: #CEE0F3;
#   border-color: #87A6D5;
# }
# .chip-list-navigation.blue[_ngcontent-sc357]   .mat-chip-list[_ngcontent-sc357]   .mat-chip.active[_ngcontent-sc357] {
#   color: #FFFFFF;
#   border-color: #FFFFFF;
# }
# [_nghost-sc357] {
#   position: relative;
#   display: block;
# }
# [_nghost-sc357]   .container[_ngcontent-sc357] {
#   position: absolute;
#   top: 48px;
#   right: 0;
#   left: 0;
#   z-index: 1;
# }</style><style ng-transition="gg-components">[_nghost-sc407] {
#   display: block;
#   padding: 20px 0;
# }</style><style ng-transition="gg-components">[_nghost-sc406]     .wca-kh-search--search-button {
#   display: none !important;
# }
# [_nghost-sc406]     .wca-kh-search--input-wrapper {
#   min-height: 3rem;
# }
# [_nghost-sc406]   .search-bar[_ngcontent-sc406] {
#   display: flex;
#   gap: 1rem;
#   flex-wrap: wrap;
# }
# @media (max-width: 599px) {
#   [_nghost-sc406]   .search-bar[_ngcontent-sc406]   wca-button[_ngcontent-sc406] {
#     flex-grow: 1;
#   }
#   [_nghost-sc406]   .search-bar[_ngcontent-sc406]   wca-button[_ngcontent-sc406]     button {
#     height: 3rem;
#     width: 100%;
#   }
# }
# [_nghost-sc406]   .search-bar[_ngcontent-sc406]   wca-button[_ngcontent-sc406]     .mat-button-disabled {
#   pointer-events: none;
# }
# [_nghost-sc406]   .search-bar[_ngcontent-sc406]   wca-kh-search[_ngcontent-sc406] {
#   flex-grow: 1;
# }
# @media (max-width: 599px) {
#   [_nghost-sc406]   .search-bar[_ngcontent-sc406]   wca-kh-search[_ngcontent-sc406] {
#     width: 100%;
#   }
# }</style><style ng-transition="gg-components">[_nghost-sc111] {
#   display: block;
#   color: #606060;
# }
# [_nghost-sc111]   .wca-kh-search--input-wrapper[_ngcontent-sc111] {
#   position: relative;
#   padding: 10px 16px;
#   border: 1px solid #606060;
#   border-radius: 10px;
#   display: flex;
#   background-color: #FFFFFF;
# }
# [_nghost-sc111]   .wca-kh-search--search-button[_ngcontent-sc111] {
#   display: block;
#   width: 26px;
#   height: 26px;
#   position: relative;
#   cursor: pointer;
# }
# [_nghost-sc111]   .wca-kh-search--search-button[_ngcontent-sc111]:after {
#   -moz-osx-font-smoothing: grayscale;
#   -webkit-font-smoothing: antialiased;
#   font-family: "glyphicons" !important;
#   font-style: normal;
#   font-variant: normal;
#   font-weight: normal;
#   line-height: 1;
#   speak: none;
#   text-transform: none;
#   content: "\e973";
#   font-weight: bold;
#   position: absolute;
#   top: 4px;
#   right: 0;
# }
# [_nghost-sc111]   .wca-kh-search__clear-button[_ngcontent-sc111] {
#   display: block;
#   width: 26px;
#   height: 26px;
#   position: relative;
#   cursor: pointer;
#   margin-right: 6px;
# }
# [_nghost-sc111]   .wca-kh-search__clear-button[_ngcontent-sc111]:after {
#   -moz-osx-font-smoothing: grayscale;
#   -webkit-font-smoothing: antialiased;
#   font-family: "glyphicons" !important;
#   font-style: normal;
#   font-variant: normal;
#   font-weight: normal;
#   line-height: 1;
#   speak: none;
#   text-transform: none;
#   content: "\e9a8";
#   font-weight: bold;
#   position: absolute;
#   top: 4px;
#   right: 0;
# }
# [_nghost-sc111]   .wca-kh-search__clear-button[_ngcontent-sc111]:after {
#   font-size: 14px;
#   top: 6px;
# }
# [_nghost-sc111]   .wca-kh-search--input[_ngcontent-sc111] {
#   font: 400 16px / 24px "Futura W01", Arial, Helvetica, sans-serif;
#   letter-spacing: 0.25px;
#   display: inline-block;
#   color: #595959;
#   border: none;
#   background-image: none;
#   background-color: #FFFFFF;
#   box-shadow: none;
#   padding: 0;
#   width: 100%;
# }
# [_nghost-sc111]   .wca-kh-search--input[_ngcontent-sc111]:focus {
#   outline-style: none;
#   box-shadow: none;
#   border-color: #FFFFFF;
# }
# [_nghost-sc111]   .wca-kh-search--input[_ngcontent-sc111]::placeholder {
#   color: #606060;
# }
#   .component.search-form-component {
#   margin-bottom: 40px;
# }</style><style ng-transition="gg-components">mat-spinner[_ngcontent-sc100] {
#   display: inline-block;
# }
#   a,   a:hover,   a:focus {
#   text-decoration: none;
# }
#   a.icon.move-icon-right,   button.icon.move-icon-right {
#   padding: 0 16px 0 24px;
# }
#   a.icon.move-icon-right[dense],   button.icon.move-icon-right[dense] {
#   padding: 6px 16px 6px 24px;
# }
#   a.icon.move-icon-right .mat-button-wrapper,   button.icon.move-icon-right .mat-button-wrapper {
#   flex-direction: row-reverse;
# }
#   a.icon:not(.move-icon-right),   button.icon:not(.move-icon-right) {
#   padding: 0 24px 0 16px;
# }
#   a.icon:not(.move-icon-right)[dense],   button.icon:not(.move-icon-right)[dense] {
#   padding: 6px 24px 6px 16px;
# }
# .full-width[_ngcontent-sc100] {
#   width: 100%;
# }</style><style ng-transition="gg-components">.mat-button .mat-button-focus-overlay,.mat-icon-button .mat-button-focus-overlay{opacity:0}.mat-button:hover:not(.mat-button-disabled) .mat-button-focus-overlay,.mat-stroked-button:hover:not(.mat-button-disabled) .mat-button-focus-overlay{opacity:.04}@media(hover: none){.mat-button:hover:not(.mat-button-disabled) .mat-button-focus-overlay,.mat-stroked-button:hover:not(.mat-button-disabled) .mat-button-focus-overlay{opacity:0}}.mat-button,.mat-icon-button,.mat-stroked-button,.mat-flat-button{box-sizing:border-box;position:relative;-webkit-user-select:none;user-select:none;cursor:pointer;outline:none;border:none;-webkit-tap-highlight-color:rgba(0,0,0,0);display:inline-block;white-space:nowrap;text-decoration:none;vertical-align:baseline;text-align:center;margin:0;min-width:64px;line-height:36px;padding:0 16px;border-radius:4px;overflow:visible}.mat-button::-moz-focus-inner,.mat-icon-button::-moz-focus-inner,.mat-stroked-button::-moz-focus-inner,.mat-flat-button::-moz-focus-inner{border:0}.mat-button.mat-button-disabled,.mat-icon-button.mat-button-disabled,.mat-stroked-button.mat-button-disabled,.mat-flat-button.mat-button-disabled{cursor:default}.mat-button.cdk-keyboard-focused .mat-button-focus-overlay,.mat-button.cdk-program-focused .mat-button-focus-overlay,.mat-icon-button.cdk-keyboard-focused .mat-button-focus-overlay,.mat-icon-button.cdk-program-focused .mat-button-focus-overlay,.mat-stroked-button.cdk-keyboard-focused .mat-button-focus-overlay,.mat-stroked-button.cdk-program-focused .mat-button-focus-overlay,.mat-flat-button.cdk-keyboard-focused .mat-button-focus-overlay,.mat-flat-button.cdk-program-focused .mat-button-focus-overlay{opacity:.12}.mat-button::-moz-focus-inner,.mat-icon-button::-moz-focus-inner,.mat-stroked-button::-moz-focus-inner,.mat-flat-button::-moz-focus-inner{border:0}.mat-raised-button{box-sizing:border-box;position:relative;-webkit-user-select:none;user-select:none;cursor:pointer;outline:none;border:none;-webkit-tap-highlight-color:rgba(0,0,0,0);display:inline-block;white-space:nowrap;text-decoration:none;vertical-align:baseline;text-align:center;margin:0;min-width:64px;line-height:36px;padding:0 16px;border-radius:4px;overflow:visible;transform:translate3d(0, 0, 0);transition:background 400ms cubic-bezier(0.25, 0.8, 0.25, 1),box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1)}.mat-raised-button::-moz-focus-inner{border:0}.mat-raised-button.mat-button-disabled{cursor:default}.mat-raised-button.cdk-keyboard-focused .mat-button-focus-overlay,.mat-raised-button.cdk-program-focused .mat-button-focus-overlay{opacity:.12}.mat-raised-button::-moz-focus-inner{border:0}.mat-raised-button._mat-animation-noopable{transition:none !important;animation:none !important}.mat-stroked-button{border:1px solid currentColor;padding:0 15px;line-height:34px}.mat-stroked-button .mat-button-ripple.mat-ripple,.mat-stroked-button .mat-button-focus-overlay{top:-1px;left:-1px;right:-1px;bottom:-1px}.mat-fab{box-sizing:border-box;position:relative;-webkit-user-select:none;user-select:none;cursor:pointer;outline:none;border:none;-webkit-tap-highlight-color:rgba(0,0,0,0);display:inline-block;white-space:nowrap;text-decoration:none;vertical-align:baseline;text-align:center;margin:0;min-width:64px;line-height:36px;padding:0 16px;border-radius:4px;overflow:visible;transform:translate3d(0, 0, 0);transition:background 400ms cubic-bezier(0.25, 0.8, 0.25, 1),box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1);min-width:0;border-radius:50%;width:56px;height:56px;padding:0;flex-shrink:0}.mat-fab::-moz-focus-inner{border:0}.mat-fab.mat-button-disabled{cursor:default}.mat-fab.cdk-keyboard-focused .mat-button-focus-overlay,.mat-fab.cdk-program-focused .mat-button-focus-overlay{opacity:.12}.mat-fab::-moz-focus-inner{border:0}.mat-fab._mat-animation-noopable{transition:none !important;animation:none !important}.mat-fab .mat-button-wrapper{padding:16px 0;display:inline-block;line-height:24px}.mat-mini-fab{box-si ...
#   display: block;
#   padding: 20px 0;
# }</style><style ng-transition="gg-components">.searchbar[_ngcontent-sc423] {
#   display: flex;
#   justify-content: space-between;
#   align-items: flex-start;
#   gap: 1rem;
# }
# @media (max-width: 599px) {
#   .searchbar[_ngcontent-sc423] {
#     flex-wrap: wrap;
#     gap: 1.5rem;
#   }
#   .searchbar[_ngcontent-sc423]   .species[_ngcontent-sc423] {
#     width: 100%;
#   }
#   .searchbar[_ngcontent-sc423]   .search-button[_ngcontent-sc423] {
#     width: 100%;
#   }
#   .searchbar[_ngcontent-sc423]   .search-button[_ngcontent-sc423]     button {
#     height: 3rem;
#     width: 100%;
#   }
# }
# [_nghost-sc423]     .targets-list .mat-form-field-wrapper, [_nghost-sc423]     .species .mat-form-field-wrapper {
#   margin-top: 0;
#   margin-bottom: 0;
#   padding-bottom: 0;
# }
# [_nghost-sc423]     .mat-chip.mat-standard-chip {
#   background-color: #F3F3F3;
#   color: #595959;
#   border-radius: 100px;
# }
# [_nghost-sc423]     .mat-chip-remove {
#   margin-left: 0 !important;
#   margin-right: 4px !important;
# }
# [_nghost-sc423]     .mat-form-field-appearance-outline .mat-form-field-outline {
#   background-color: white;
# }
# [_nghost-sc423]     .mat-chip-list-wrapper {
#   margin: -6px;
#   min-height: 40px;
# }
# [_nghost-sc423]     mat-chip-list.chip-list-only-visible .mat-chip-list-wrapper {
#   flex-wrap: nowrap;
# }
# [_nghost-sc423]     .targets-list.desktop mat-form-field {
#   overflow: hidden;
# }
# [_nghost-sc423]     .targets-list.desktop mat-form-field .mat-form-field-flex {
#   max-height: 52px;
# }
# [_nghost-sc423]     .targets-list.desktop .mat-form-field-appearance-outline .mat-form-field-suffix {
#   margin: auto;
#   top: unset;
# }
# [_nghost-sc423]     .mat-form-field-subscript-wrapper {
#   margin-top: 26px;
# }
# .targets-list[_ngcontent-sc423] {
#   width: 80%;
# }
# .targets-list[_ngcontent-sc423]   mat-form-field[_ngcontent-sc423] {
#   width: 100%;
# }
# .targets-list[_ngcontent-sc423]   mat-chip[_ngcontent-sc423] {
#   font-weight: 500;
#   color: #606060;
#   white-space: nowrap;
#   border-radius: 10px;
# }
# @media (max-width: 599px) {
#   .targets-list[_ngcontent-sc423] {
#     width: 100%;
#   }
# }
# .targets-list.hide-mobile[_ngcontent-sc423] {
#   display: none;
# }
# .add-target-hint[_ngcontent-sc423], .add-target-hint[_ngcontent-sc423]    > button[_ngcontent-sc423], .hidden-chip-counter[_ngcontent-sc423] {
#   border: none !important;
#   background-color: #F2F7FC !important;
#   color: #004D9F !important;
# }
# .add-target-hint[_ngcontent-sc423]   span[_ngcontent-sc423] {
#   padding-left: 6px;
# }
# .import-targets[_ngcontent-sc423] {
#   display: flex;
# }
# .import-targets[_ngcontent-sc423]   .divider[_ngcontent-sc423] {
#   border-left: 1px solid black;
# }
# .import-targets[_ngcontent-sc423]   .import-targets-btn[_ngcontent-sc423] {
#   display: flex;
#   align-items: center;
#   margin: 0 8px;
#   cursor: pointer;
# }
# .import-targets[_ngcontent-sc423]   .import-targets-btn[_ngcontent-sc423]   mat-icon[_ngcontent-sc423] {
#   margin-right: 8px;
# }
# .one-line-chip-input[_ngcontent-sc423]   .chip-list-all[_ngcontent-sc423] {
#   visibility: hidden;
# }
# .one-line-chip-input[_ngcontent-sc423]   mat-chip.add-target-hint[_ngcontent-sc423] {
#   min-width: 120px;
#   max-width: 120px;
# }
# mat-option.sticky[_ngcontent-sc423] {
#   position: sticky;
#   bottom: 0;
#   background-color: white;
# }
# mat-option.sticky[_ngcontent-sc423]   .remove-all[_ngcontent-sc423] {
#   font: 400 16px / 24px "Futura W01", Arial, Helvetica, sans-serif;
#   letter-spacing: 0.4px;
#   float: left;
#   color: #004D9F;
#   cursor: pointer;
# }</style><style ng-transition="gg-components">[_nghost-sc159] {
#   display: flex;
#   position: relative;
#   width: 100%;
# }
#   .mat-autocomplete-panel mat-option {
#   font-weight: 400;
#   font-size: 16px;
#   line-height: 25px;
# }
#   mat-form-field.warning .mat-step-header .mat-step-icon-selected,   mat-form-field.warning .mat-step-header .mat-step-icon-state-done,   mat-form-field.warning .mat-step-header .mat-step-icon-state-edit {
#   background-color: #754E00 !important;
# }
#   mat-form-field.warning mat-label,   mat-form-field.warning .mat-placeholder-required,   mat-form-field.warning mat-hint.warning-message,   mat-form-field.warning mat-icon {
#   color: #754E00 !important;
# }
# @media (max-width: 599px) {
#     mat-form-field.warning mat-label.hide-xs,   mat-form-field.warning .mat-placeholder-required.hide-xs,   mat-form-field.warning mat-hint.warning-message.hide-xs,   mat-form-field.warning mat-icon.hide-xs {
#     display: none;
#   }
# }
#   mat-form-field.warning .mat-form-field-outline {
#   color: #754E00 !important;
# }
#   mat-form-field.warning.mat-form-field-appearance-outline.mat-focused .mat-form-field-outline-thick {
#   color: #754E00 !important;
# }
#   mat-form-field.warning.mat-form-field-appearance-outline:not(.mat-form-field-disabled) .mat-form-field-flex:hover .mat-form-field-outline .mat-form-field-outline-start,   mat-form-field.warning.mat-form-field-appearance-outline:not(.mat-form-field-disabled) .mat-form-field-flex:hover .mat-form-field-outline .mat-form-field-outline-gap,   mat-form-field.warning.mat-form-field-appearance-outline:not(.mat-form-field-disabled) .mat-form-field-flex:hover .mat-form-field-outline .mat-form-field-outline-end,   mat-form-field.warning.mat-form-field-appearance-outline:not(.mat-form-field-disabled) .mat-form-field-flex:hover .mat-form-field-outline-thick .mat-form-field-outline-start,   mat-form-field.warning.mat-form-field-appearance-outline:not(.mat-form-field-disabled) .mat-form-field-flex:hover .mat-form-field-outline-thick .mat-form-field-outline-gap,   mat-form-field.warning.mat-form-field-appearance-outline:not(.mat-form-field-disabled) .mat-form-field-flex:hover .mat-form-field-outline-thick .mat-form-field-outline-end {
#   color: #754E00 !important;
# }
#   mat-form-field.warning.mat-form-field-appearance-outline.mat-focused .mat-form-field-outline,   mat-form-field.warning.mat-form-field-appearance-outline.mat-focused .mat-form-field-outline.mat-form-field-outline-thick {
#   color: #754E00 !important;
# }
#   mat-form-field.warning.mat-form-field-appearance-outline.mat-focused .mat-form-field-outline .mat-form-field-outline-start,   mat-form-field.warning.mat-form-field-appearance-outline.mat-focused .mat-form-field-outline .mat-form-field-outline-gap,   mat-form-field.warning.mat-form-field-appearance-outline.mat-focused .mat-form-field-outline .mat-form-field-outline-end,   mat-form-field.warning.mat-form-field-appearance-outline.mat-focused .mat-form-field-outline.mat-form-field-outline-thick .mat-form-field-outline-start,   mat-form-field.warning.mat-form-field-appearance-outline.mat-focused .mat-form-field-outline.mat-form-field-outline-thick .mat-form-field-outline-gap,   mat-form-field.warning.mat-form-field-appearance-outline.mat-focused .mat-form-field-outline.mat-form-field-outline-thick .mat-form-field-outline-end {
#   color: #754E00 !important;
# }
#   mat-form-field.warning .mat-input-element {
#   caret-color: #754E00 !important;
# }
# [_nghost-sc159]     div.mat-form-field-suffix {
#   margin-left: 16px;
#   top: -4px;
#   color: #BCBCBB;
# }
# .text-form-field[_ngcontent-sc159] {
#   width: 100%;
#   font-family: "Futura W01", Arial, Helvetica, sans-serif;
# }
# .text-form-field[_ngcontent-sc159]   input[_ngcontent-sc159]:-webkit-autofill, .text-form-field[_ngcontent-sc159]   input[_ngcontent-sc159]:-webkit-autofill:hover, .text-form-field[_ngcontent-sc159]   input[_ngcontent-sc159]:-webkit-autofill:focus, .text-form-field[_ngcontent-sc159]   input[_ngcontent-sc159]:-webkit-autofill:active {
#   -webkit-animation-name: autofill;
#   -webkit-animation-fill-mode: both;
# }
# .text-form-field[_ngcontent-sc159]   mat-select[_ngcontent-sc159] {
#   height: 28px;
#   line-height: 28px;
# }
# .text-form-field[_ngcontent-sc159]   mat-select[_ngcontent-sc159]     .mat-select-arrow-wrapper {
#   transform: none;
# }
# .text-form-field--hidden[_ngcontent-sc159] {
#   display: none;
# }
# .checkbox-form-field[_ngcontent-sc159] {
#   width: 100%;
# }
# .checkbox-form-field[_ngcontent-sc159]     .mat-checkbox-inner-container {
#   margin-top: 5px;
# }
# .checkbox-form-field[_ngcontent-sc159]     .mat-checkbox-label {
#   font-size: 16px;
#   white-space: normal;
# }
# ...
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/agranulocyte-adhesion-and-diapedesis">Agranulocytes Adhesion</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/antigen-presentation-pathway">Antigen Presentation</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/assembly-of-rna-polymerase-ii-complex">RNA Polymerase 2</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/cell-cycle-g1-s-checkpoint-regulation">G1 Checkpoint Cell Cycle</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/cellular-activity-metabolism-and-homeostasis-pathways/transcriptional-regulation">Transcriptional Regulation</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/creb-signaling-in-neurons">CREB</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/erk-mapk-signaling">MAPK and ERK</a></p></app-text><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></app-dynamic-component></div><!-- --></div><div _ngcontent-sc311="" class="ng-star-inserted"><div _ngcontent-sc311="" class="panel-subitem ng-star-inserted"><app-dynamic-component _ngcontent-sc311="" _nghost-sc307=""><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><app-text _ngcontent-sc307="" _nghost-sc329="" class="ng-star-inserted"><p _ngcontent-sc329="" class="rich-text"></p><p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/general-signal-transduction-pathways/pi3k-akt-mtor-signaling">PI3 AKT mTOR</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/glucocorticoid-receptor-signaling">Glucocorticoid Receptor</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/granzyme-a-signaling">Granzyme</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/hippo-signaling">Hippo Signaling</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/oxidative-phosphorylation">Oxygen Phosphorylation</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/phagosome-formation">Phagosome</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/ppar-signaling">PPAR</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/tight-junction-signaling">Tight Junction</a></p></app-text><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></app-dynamic-component></div><!-- --></div><div _ngcontent-sc311="" class="ng-star-inserted"><div _ngcontent-sc311="" class="panel-subitem ng-star-inserted"><app-dynamic-component _ngcontent-sc311="" _nghost-sc307=""><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><app-text _ngcontent-sc307="" _nghost-sc329="" class="ng-star-inserted"><p _ngcontent-sc329="" class="rich-text"></p><p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/wnt-beta-catenin-signaling">Beta Catenin</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/cleavage-and-polyadenylation-of-pre-mrna">Polyadenylation</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/leukocyte-extravasation-signaling">Leukocyte Extravasation Signaling</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/adipogenesis-pathway">Adipogenesis</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/apoptosis-signaling">Apoptosis Signaling</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/oxidative-phosphorylation">Oxidative Phosphorylation</a></p>
# <p><a href="https://geneglobe.qiagen.com/us/knowledge/pathways/eif2-signaling">EIF2 Signaling</a></p></app-text><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></app-dynamic-component></div><!-- --></div><!-- --></div></app-columns-component><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></app-dynamic-component><!-- --></div></div></div></app-layout-wrapper><!-- --></div><!-- --><!-- --><!-- --><!-- --></app-mat-components-renderer></app-mat-landing-page><!-- --><router-outlet name="componentsRenderer"></router-outlet><!-- --><gg-footer _nghost-sc118=""><wca-footer _ngcontent-sc118="" _nghost-sc117="" data-onedatalayer-source="Footer"><div _ngcontent-sc117="" class="footer-top"><div _ngcontent-sc117="" class="wrap"><div _ngcontent-sc117="" class="country-language-selector box"><div _ngcontent-sc117="">Country and Language</div><wca-footer-country _ngcontent-sc117="" _nghost-sc115=""><div _ngcontent-sc115="" class="select-wrap select-wrap--lang"><select _ngcontent-sc115="" data-country="us"><option _ngcontent-sc115="" value="af"> Afghanistan </option><!-- --><option _ngcontent-sc115="" value="al"> Albania </option><!-- --><option _ngcontent-sc115="" value="dz"> Algeria </option><!-- --><option _ngcontent-sc115="" value="as"> American Samoa </option><!-- --><option _ngcontent-sc115="" value="ad"> Andorra </option><!-- --><option _ngcontent-sc115="" value="ao"> Angola </option><!-- --><option _ngcontent-sc115="" value="ai"> Anguilla </option><!-- --><option _ngcontent-sc115="" value="aq"> Antarctica </option><!-- --><option _ngcontent-sc115="" value="ag"> Antigua and Barbuda </option><!-- --><option _ngcontent-sc115="" value="ar"> Argentina </option><!-- --><option _ngcontent-sc115="" value="am"> Armenia </option><!-- --><option _ngcontent-sc115="" value="aw"> Aruba </option><!-- --><option _ngcontent-sc115="" value="au"> Australia </option><!-- --><option _ngcontent-sc115="" value="at"> Austria </option><!-- --><option _ngcontent-sc115="" value="az"> Azerbaijan </option><!-- --><option _ngcontent-sc115="" value="bs"> Bahamas </option><!-- --><option _ngcontent-sc115="" value="bh"> Bahrain </option><!-- --><option _ngcontent-sc115="" value="bd"> Bangladesh </option><!-- --><option _ngcontent-sc115="" value="bb"> Barbados </option><!-- --><option _ngcontent-sc115="" value="be"> Belgium </option><!-- --><option _ngcontent-sc115="" value="bz"> Belize </option><!-- --><option _ngcontent-sc115="" value="bj"> Benin </option><!-- --><option _ngcontent-sc115="" value="bm"> Bermuda </option><!-- --><option _ngcontent-sc115="" value="bt"> Bhutan </option><!-- --><option _ngcontent-sc115="" value="bo"> Bolivia (Plurinational State of) </option><!-- --><option _ngcontent-sc115="" value="ba"> Bosnia and Herzegovina </option><!-- --><option _ngcontent-sc115="" value="bw"> Botswana </option><!-- --><option _ngcontent-sc115="" value="bv"> Bouvet Island </option><!-- --><option _ngcontent-sc115="" value="br"> Brazil </option><!-- --><option _ngcontent-sc115="" value="io"> British Indian Ocean Territory </option><!-- --><option _ngcontent-sc115="" value="vg"> British Virgin Islands </option><!-- --><option _ngcontent-sc115="" value="bn"> Brunei Darussalam (Brunei) </option><!-- --><option _ngcontent-sc115="" value="bg"> Bulgaria </option><!-- --><option _ngcontent-sc115="" value="bf"> Burkina Faso </option><!-- --><option _ngcontent-sc115="" value="bi"> Burundi </option><!-- --><option _ngcontent-sc115="" value="cv"> Cabo Verde </option><!-- --><option _ngcontent-sc115="" value="kh"> Cambodia </option><!-- --><option _ngcontent-sc115="" value="cm"> Cameroon </op ...
# <script data-ggfile="js" src="/assets/js/lib-gg_lib_1.6.5.js" type="text/javascript"></script>
# <script src="runtime.8f3195aa3e3c622d.js" type="module"></script><script src="polyfills.15e925418bc26fb1.js" type="module"></script><script src="main.cb3ad388c0147aa0.js" type="module"></script>
# <div aria-atomic="true" aria-live="polite" class="cdk-live-announcer-element cdk-visually-hidden"></div><script id="gg-components-state" type="application/json">{&q;ui-app-configuration&q;:&q;...&q;,&q;/api/cms/labels?path=/Global-Web-Content/Header/HeaderBanner37a6259cc0c1dae299a7866489dff0bd&q;:{&q;labels&q;:{&q;urlCriteriaAll&q;:&q;customize&q;,&q;urlCriteriaAny&q;:&q;&q;,&q;showHeaderBanner&q;:&q;&q;,&q;Color&q;:&q;red&q;,&q;Content&q;:&q;🛠️ &l;span style=\&q;color: white;\&q;&g;Our custom design pipelines are undergoing maintenance. They should be back up shortly.🛠️&l;/span&g;&q;}},&q;/api/cms/page/footer37a6259cc0c1dae299a7866489dff0bd&q;:{&q;textCountryAndLanguage&q;:&q;Country and Language&q;,&q;termsAndConditionsData&q;:[{&q;title&q;:&q;Privacy Policy&q;,&q;link&q;:&q;https://www.qiagen.com/us/trademarks-and-disclaimers/privacy-policy&q;},{&q;title&q;:&q;Trademarks and Disclaimers&q;,&q;link&q;:&q;https://www.qiagen.com/us/trademarks-and-disclaimers&q;},{&q;title&q;:&q;Impressum&q;,&q;link&q;:&q;https://www.qiagen.com/us/trademarks-and-disclaimers/impressum&q;}],&q;contactUsData&q;:{&q;title&q;:&q;Contact us&q;,&q;contactCustomerCare&q;:&q;https://www.qiagen.com/us/support/order-support/&q;,&q;contactTechnicalService&q;:&q;https://www.qiagen.com/us/support/technical-support/&q;},&q;followUsData&q;:{&q;title&q;:&q;Follow us&q;,&q;twitter&q;:&q;https://x.com/qiagen&q;,&q;linkedIn&q;:&q;https://www.linkedin.com/company/qiagen&q;,&q;facebook&q;:&q;https://www.facebook.com/QIAGEN&q;,&q;instagram&q;:&q;https://www.instagram.com/QIAGEN&q;,&q;youtube&q;:&q;https://www.youtube.com/QIAGEN&q;}},&q;/api/cms/page/header37a6259cc0c1dae299a7866489dff0bd&q;:{&q;headerText&q;:&q;GeneGlobe&q;,&q;homePageLink&q;:&q;/&q;,&q;qiagenLogoLink&q;:&q;/&q;,&q;cookieDisclaimer&q;:{&q;disclaimer&q;:&q;You can accept or revoke the cookies used on this website at any time with the selection below or by adjusting your cookie settings. For complete details about our cookies, see our &l;a href=\&q;https://www.qiagen.com/us/trademarks-and-disclaimers/cookies-overview\&q;&g;Cookie Policy&l;/a&g;.&q;,&q;confirm&q;:&q;Confirm&q;},&q;menuItems&q;:[{&q;title&q;:&q;Applications&q;,&q;link&q;:&q;/applications&q;,&q;teaser&q;:{&q;title&q;:&q;Your Gateway to Tailored Genomic Solutions&q;,&q;description&q;:&q;&l;p&g;Explore tailored genomic solutions on GeneGlobe&s;s Panel Finder page. Dive into curated selections across various applications, finding the perfect panel for your research needs.&l;/p&g;\n&l;p&g;&l;strong&g;Click here and embark on your genomic discovery journey now!&l;/strong&g;&l;/p&g;&q;,&q;imageUrl&q;:&q;/media/0e1dbf42-e328-4d40-af3a-cd05c303e87b&q;,&q;link&q;:&q;https://geneglobe.qiagen.com/search/panel-finder&q;},&q;items&q;:[{&q;title&q;:&q;Next-Generation Sequencing&q;,&q;link&q;:&q;/applications/next-generation-sequencing&q;,&q;teaser&q;:null,&q;items&q;:[{&q;title&q;:&q;DNA&q;,&q;link&q;:&q;/applications/next-generation-sequencing/dna&q;,&q;teaser&q;:null,&q;items&q;:[]},{&q;title&q;:&q;miRNA&q;,&q;link&q;:&q;/applications/next-generation-sequencing/mirna&q;,&q;teaser&q;:null,&q;items&q;:[]},{&q;title&q;:&q;RNA &a; lncRNA&q;,&q;link&q;:&q;/applications/next-generation-sequencing/rna-lncrna&q;,&q;teaser&q;:null,&q;items&q;:[]}]},{&q;title&q;:&q;Digital PCR&q;,&q;link&q;:&q;/applications/digital-pcr&q;,&q;teaser&q;:null,&q;items&q;:[{&q;title&q;:&q;DNA&q;,&q;link&q;:&q;/applications/digital-pcr/dna&q;,&q;teaser&q;:null,&q;items&q;:[]},{&q;title&q;:&q;miRNA&q;,&q;link&q;:&q;/applications/digital-pcr/mirna&q;,&q;teaser&q;:null,&q;items&q;:[]},{&q;title&q;:&q;RNA &a; lncRNA&q;,&q;link&q;:&q;/applications/digital-pcr/rna-lncrna&q;,&q;teaser&q;:null,&q;items&q;:[]},{&q;title&q;:&q;Cancer and Oncology Research&q;,&q;link&q;:&q;/applications/digital-pcr/cancer-research&q;,&q;teaser&q;:null,&q;items&q;:[]}]},{&q;title&q;:&q;Real-Time PCR&q;,&q;link&q;:&q;/applications/real-time-pcr&q;,&q;teaser&q;:null,&q;items&q;:[{&q;title&q;:&q;DNA&q;,&q;link&q; ...
